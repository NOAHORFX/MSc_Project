# %%
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
from data_preprocessing import create_segmentation_datasets
# Out:
# 2025-08-11 03:28:34.968278: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-11 03:28:34.999392: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-11 03:28:35.600674: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
image_dir = '/home/featurize/data/segmentation_dataset/images'
mask_dir = '/home/featurize/data/segmentation_dataset/masks'

dataset_train, dataset_val, dataset_test = create_segmentation_datasets(image_dir=image_dir, mask_dir=mask_dir, batch_size=24, val_split=0.2, test_split=0.1)

for imgs, masks in dataset_train.take(1):
    print('Train batch images:', imgs.shape, 'masks:', masks.shape)
for imgs, masks in dataset_val.take(1):
    print('Val batch images:', imgs.shape, 'masks:', masks.shape)
for imgs, masks in dataset_test.take(1):
    print('Test batch images:', imgs.shape, 'masks:', masks.shape)
# Out:
# Training samples: 4634, validation samples: 1324, test samples: 662
# 2025-08-11 03:28:36.283485: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:28:36.287304: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:28:36.287473: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:28:36.289455: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:28:36.289589: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:28:36.289691: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:28:36.680852: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:28:36.681019: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:28:36.681134: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:28:36.681212: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-08-11 03:28:36.681232: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22108 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:10:00.0, compute capability: 8.9
# Train batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)
# Val batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)
# Test batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)

# %%
# import tensorflow as tf
# import numpy as np
# from collections import Counter

# def count_classes_in_dataset(dataset):
#     total_counter = Counter()

#     for batch in dataset:
#         images, masks = batch
#         flat_masks = tf.reshape(masks, [-1])
#         result = tf.unique_with_counts(flat_masks)
#         unique_vals = result.y
#         counts = result.count

#         for val, count in zip(unique_vals.numpy(), counts.numpy()):
#             total_counter[int(val)] += int(count)

#     print("\n Dataset 中的类别总分布：")
#     for cls in sorted(total_counter.keys()):
#         print(f"类 {cls}: {total_counter[cls]} 像素")

#     return total_counter

# # 示例调用
# count_classes_in_dataset(dataset_train)

# %%
import matplotlib.pyplot as plt
import numpy as np

for img_batch, mask_batch in dataset_train.take(1):
    img = img_batch[0].numpy()
    mask = mask_batch[0].numpy()

    # 1. 将图像从 [-1, 1] 转回 [0, 1] 浮点图像
    img_display = (img + 1.0) / 2.0
    img_display = np.clip(img_display, 0.0, 1.0)

    # 2. 将 mask squeeze，转换为 uint8，用于灰度显示
    mask_display = np.squeeze(mask).astype(np.uint8)

    # 可视化
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(img_display, cmap='gray', vmin=0.0, vmax=1.0)  # 显式指定范围
    plt.axis('off')
    plt.title("Augmented Image")

    plt.subplot(1, 2, 2)
    plt.imshow(mask_display, cmap='gray', vmin=0, vmax=1)  # 确保 0=黑，1=白
    plt.axis('off')
    plt.title("Mask")

    plt.show()

# %%
from model_test import model

# %%
model = model(img_height=384, img_width=508, classes=2)
model.summary()
# Out:
# *** Output Shape: (None, 384, 508, 2) ***
# Model: "ENet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 384, 508, 3)]        0         []
#
#  init_conv (Conv2D)          (None, 192, 254, 13)         351       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 192, 254, 13)         52        ['init_conv[0][0]']
#  Normalization)
#
#  init_conv_prelu (PReLU)     (None, 192, 254, 13)         13        ['batch_normalization[0][0]']
#
#  init_pool (MaxPooling2D)    (None, 192, 254, 3)          0         ['input_1[0][0]']
#
#  init_concat (Concatenate)   (None, 192, 254, 16)         0         ['init_conv_prelu[0][0]',
#                                                                      'init_pool[0][0]']
#
#  bottleneck1_0_reduce (Conv  (None, 192, 254, 16)         256       ['init_concat[0][0]']
#  2D)
#
#  batch_normalization_1 (Bat  (None, 192, 254, 16)         64        ['bottleneck1_0_reduce[0][0]']
#  chNormalization)
#
#  bottleneck1_0_reduce_prelu  (None, 192, 254, 16)         16        ['batch_normalization_1[0][0]'
#   (PReLU)                                                           ]
#
#  bottleneck1_0_conv (Conv2D  (None, 96, 127, 16)          2304      ['bottleneck1_0_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_2 (Bat  (None, 96, 127, 16)          64        ['bottleneck1_0_conv[0][0]']
#  chNormalization)
#
#  bottleneck1_0_conv_prelu (  (None, 96, 127, 16)          16        ['batch_normalization_2[0][0]'
#  PReLU)                                                             ]
#
#  bottleneck1_0_expand (Conv  (None, 96, 127, 64)          1024      ['bottleneck1_0_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck1_0_main_proj (C  (None, 96, 127, 64)          1024      ['init_concat[0][0]']
#  onv2D)
#
#  bottleneck1_0_expand_bn (B  (None, 96, 127, 64)          256       ['bottleneck1_0_expand[0][0]']
#  atchNormalization)
#
#  bottleneck1_0_main_proj_bn  (None, 96, 127, 64)          256       ['bottleneck1_0_main_proj[0][0
#   (BatchNormalization)                                              ]']
#
#  bottleneck1_0_drop (Spatia  (None, 96, 127, 64)          0         ['bottleneck1_0_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck1_0_align (Lambd  (None, 96, 127, 64)          0         ['bottleneck1_0_drop[0][0]',
#  a)                                                                  'bottleneck1_0_main_proj_bn[0
#                                                                     ][0]']
#
#  bottleneck1_0_add (Add)     (None, 96, 127, 64)          0         ['bottleneck1_0_main_proj_bn[0
#                                                                     ][0]',
#                                                                      'bottleneck1_0_align[0][0]']
#
#  bottleneck1_0_out_prelu (P  (None, 96, 127, 64)          64        ['bottleneck1_0_add[0][0]']
#  ReLU)
#
#  bottleneck1_1_reduce (Conv  (None, 96, 127, 16)          1024      ['bottleneck1_0_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_3 (Bat  (None, 96, 127, 16)          64        ['bottleneck1_1_reduce[0][0]']
#  chNormalization)
#
#  bottleneck1_1_reduce_prelu  (None, 96, 127, 16)          16        ['batch_normalization_3[0][0]'
#   (PReLU)                                                           ]
#
#  bottleneck1_1_conv (Conv2D  (None, 96, 127, 16)          2304      ['bottleneck1_1_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_4 (Bat  (None, 96, 127, 16)          64        ['bottleneck1_1_conv[0][0]']
#  chNormalization)
#
#  bottleneck1_1_conv_prelu (  (None, 96, 127, 16)          16        ['batch_normalization_4[0][0]'
#  PReLU)                                                             ]
#
#  bottleneck1_1_expand (Conv  (None, 96, 127, 64)          1024      ['bottleneck1_1_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck1_1_expand_bn (B  (None, 96, 127, 64)          256       ['bottleneck1_1_expand[0][0]']
#  atchNormalization)
#
#  bottleneck1_1_drop (Spatia  (None, 96, 127, 64)          0         ['bottleneck1_1_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck1_1_align (Lambd  (None, 96, 127, 64)          0         ['bottleneck1_1_drop[0][0]',
#  a)                                                                  'bottleneck1_0_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck1_1_add (Add)     (None, 96, 127, 64)          0         ['bottleneck1_0_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck1_1_align[0][0]']
#
#  bottleneck1_1_out_prelu (P  (None, 96, 127, 64)          64        ['bottleneck1_1_add[0][0]']
#  ReLU)
#
#  bottleneck1_2_reduce (Conv  (None, 96, 127, 16)          1024      ['bottleneck1_1_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_5 (Bat  (None, 96, 127, 16)          64        ['bottleneck1_2_reduce[0][0]']
#  chNormalization)
#
#  bottleneck1_2_reduce_prelu  (None, 96, 127, 16)          16        ['batch_normalization_5[0][0]'
#   (PReLU)                                                           ]
#
#  bottleneck1_2_conv (Conv2D  (None, 96, 127, 16)          2304      ['bottleneck1_2_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_6 (Bat  (None, 96, 127, 16)          64        ['bottleneck1_2_conv[0][0]']
#  chNormalization)
#
#  bottleneck1_2_conv_prelu (  (None, 96, 127, 16)          16        ['batch_normalization_6[0][0]'
#  PReLU)                                                             ]
#
#  bottleneck1_2_expand (Conv  (None, 96, 127, 64)          1024      ['bottleneck1_2_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck1_2_expand_bn (B  (None, 96, 127, 64)          256       ['bottleneck1_2_expand[0][0]']
#  atchNormalization)
#
#  bottleneck1_2_drop (Spatia  (None, 96, 127, 64)          0         ['bottleneck1_2_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck1_2_align (Lambd  (None, 96, 127, 64)          0         ['bottleneck1_2_drop[0][0]',
#  a)                                                                  'bottleneck1_1_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck1_2_add (Add)     (None, 96, 127, 64)          0         ['bottleneck1_1_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck1_2_align[0][0]']
#
#  bottleneck1_2_out_prelu (P  (None, 96, 127, 64)          64        ['bottleneck1_2_add[0][0]']
#  ReLU)
#
#  bottleneck1_3_reduce (Conv  (None, 96, 127, 16)          1024      ['bottleneck1_2_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_7 (Bat  (None, 96, 127, 16)          64        ['bottleneck1_3_reduce[0][0]']
#  chNormalization)
#
#  bottleneck1_3_reduce_prelu  (None, 96, 127, 16)          16        ['batch_normalization_7[0][0]'
#   (PReLU)                                                           ]
#
#  bottleneck1_3_conv (Conv2D  (None, 96, 127, 16)          2304      ['bottleneck1_3_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_8 (Bat  (None, 96, 127, 16)          64        ['bottleneck1_3_conv[0][0]']
#  chNormalization)
#
#  bottleneck1_3_conv_prelu (  (None, 96, 127, 16)          16        ['batch_normalization_8[0][0]'
#  PReLU)                                                             ]
#
#  bottleneck1_3_expand (Conv  (None, 96, 127, 64)          1024      ['bottleneck1_3_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck1_3_expand_bn (B  (None, 96, 127, 64)          256       ['bottleneck1_3_expand[0][0]']
#  atchNormalization)
#
#  bottleneck1_3_drop (Spatia  (None, 96, 127, 64)          0         ['bottleneck1_3_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck1_3_align (Lambd  (None, 96, 127, 64)          0         ['bottleneck1_3_drop[0][0]',
#  a)                                                                  'bottleneck1_2_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck1_3_add (Add)     (None, 96, 127, 64)          0         ['bottleneck1_2_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck1_3_align[0][0]']
#
#  bottleneck1_3_out_prelu (P  (None, 96, 127, 64)          64        ['bottleneck1_3_add[0][0]']
#  ReLU)
#
#  bottleneck1_4_reduce (Conv  (None, 96, 127, 16)          1024      ['bottleneck1_3_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_9 (Bat  (None, 96, 127, 16)          64        ['bottleneck1_4_reduce[0][0]']
#  chNormalization)
#
#  bottleneck1_4_reduce_prelu  (None, 96, 127, 16)          16        ['batch_normalization_9[0][0]'
#   (PReLU)                                                           ]
#
#  bottleneck1_4_conv (Conv2D  (None, 96, 127, 16)          2304      ['bottleneck1_4_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_10 (Ba  (None, 96, 127, 16)          64        ['bottleneck1_4_conv[0][0]']
#  tchNormalization)
#
#  bottleneck1_4_conv_prelu (  (None, 96, 127, 16)          16        ['batch_normalization_10[0][0]
#  PReLU)                                                             ']
#
#  bottleneck1_4_expand (Conv  (None, 96, 127, 64)          1024      ['bottleneck1_4_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck1_4_expand_bn (B  (None, 96, 127, 64)          256       ['bottleneck1_4_expand[0][0]']
#  atchNormalization)
#
#  bottleneck1_4_drop (Spatia  (None, 96, 127, 64)          0         ['bottleneck1_4_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck1_4_align (Lambd  (None, 96, 127, 64)          0         ['bottleneck1_4_drop[0][0]',
#  a)                                                                  'bottleneck1_3_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck1_4_add (Add)     (None, 96, 127, 64)          0         ['bottleneck1_3_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck1_4_align[0][0]']
#
#  bottleneck1_4_out_prelu (P  (None, 96, 127, 64)          64        ['bottleneck1_4_add[0][0]']
#  ReLU)
#
#  bottleneck2_0_reduce (Conv  (None, 96, 127, 16)          1024      ['bottleneck1_4_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_11 (Ba  (None, 96, 127, 16)          64        ['bottleneck2_0_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck2_0_reduce_prelu  (None, 96, 127, 16)          16        ['batch_normalization_11[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck2_0_conv (Conv2D  (None, 48, 64, 16)           2304      ['bottleneck2_0_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_12 (Ba  (None, 48, 64, 16)           64        ['bottleneck2_0_conv[0][0]']
#  tchNormalization)
#
#  bottleneck2_0_conv_prelu (  (None, 48, 64, 16)           16        ['batch_normalization_12[0][0]
#  PReLU)                                                             ']
#
#  bottleneck2_0_expand (Conv  (None, 48, 64, 128)          2048      ['bottleneck2_0_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck2_0_main_proj (C  (None, 48, 64, 128)          8192      ['bottleneck1_4_out_prelu[0][0
#  onv2D)                                                             ]']
#
#  bottleneck2_0_expand_bn (B  (None, 48, 64, 128)          512       ['bottleneck2_0_expand[0][0]']
#  atchNormalization)
#
#  bottleneck2_0_main_proj_bn  (None, 48, 64, 128)          512       ['bottleneck2_0_main_proj[0][0
#   (BatchNormalization)                                              ]']
#
#  bottleneck2_0_drop (Spatia  (None, 48, 64, 128)          0         ['bottleneck2_0_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck2_0_align (Lambd  (None, 48, 64, 128)          0         ['bottleneck2_0_drop[0][0]',
#  a)                                                                  'bottleneck2_0_main_proj_bn[0
#                                                                     ][0]']
#
#  bottleneck2_0_add (Add)     (None, 48, 64, 128)          0         ['bottleneck2_0_main_proj_bn[0
#                                                                     ][0]',
#                                                                      'bottleneck2_0_align[0][0]']
#
#  bottleneck2_0_out_prelu (P  (None, 48, 64, 128)          128       ['bottleneck2_0_add[0][0]']
#  ReLU)
#
#  bottleneck2_1_reduce (Conv  (None, 48, 64, 32)           4096      ['bottleneck2_0_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_13 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_1_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck2_1_reduce_prelu  (None, 48, 64, 32)           32        ['batch_normalization_13[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck2_1_conv (Conv2D  (None, 48, 64, 32)           9216      ['bottleneck2_1_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_14 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_1_conv[0][0]']
#  tchNormalization)
#
#  bottleneck2_1_conv_prelu (  (None, 48, 64, 32)           32        ['batch_normalization_14[0][0]
#  PReLU)                                                             ']
#
#  bottleneck2_1_expand (Conv  (None, 48, 64, 128)          4096      ['bottleneck2_1_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck2_1_expand_bn (B  (None, 48, 64, 128)          512       ['bottleneck2_1_expand[0][0]']
#  atchNormalization)
#
#  bottleneck2_1_drop (Spatia  (None, 48, 64, 128)          0         ['bottleneck2_1_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck2_1_align (Lambd  (None, 48, 64, 128)          0         ['bottleneck2_1_drop[0][0]',
#  a)                                                                  'bottleneck2_0_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck2_1_add (Add)     (None, 48, 64, 128)          0         ['bottleneck2_0_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck2_1_align[0][0]']
#
#  bottleneck2_1_out_prelu (P  (None, 48, 64, 128)          128       ['bottleneck2_1_add[0][0]']
#  ReLU)
#
#  bottleneck2_2_reduce (Conv  (None, 48, 64, 32)           4096      ['bottleneck2_1_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_15 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_2_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck2_2_reduce_prelu  (None, 48, 64, 32)           32        ['batch_normalization_15[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck2_2_conv (Conv2D  (None, 48, 64, 32)           9216      ['bottleneck2_2_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_16 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_2_conv[0][0]']
#  tchNormalization)
#
#  bottleneck2_2_conv_prelu (  (None, 48, 64, 32)           32        ['batch_normalization_16[0][0]
#  PReLU)                                                             ']
#
#  bottleneck2_2_expand (Conv  (None, 48, 64, 128)          4096      ['bottleneck2_2_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck2_2_expand_bn (B  (None, 48, 64, 128)          512       ['bottleneck2_2_expand[0][0]']
#  atchNormalization)
#
#  bottleneck2_2_drop (Spatia  (None, 48, 64, 128)          0         ['bottleneck2_2_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck2_2_align (Lambd  (None, 48, 64, 128)          0         ['bottleneck2_2_drop[0][0]',
#  a)                                                                  'bottleneck2_1_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck2_2_add (Add)     (None, 48, 64, 128)          0         ['bottleneck2_1_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck2_2_align[0][0]']
#
#  bottleneck2_2_out_prelu (P  (None, 48, 64, 128)          128       ['bottleneck2_2_add[0][0]']
#  ReLU)
#
#  bottleneck2_3_reduce (Conv  (None, 48, 64, 32)           4096      ['bottleneck2_2_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_17 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_3_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck2_3_reduce_prelu  (None, 48, 64, 32)           32        ['batch_normalization_17[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck2_3_asym_5x1 (Co  (None, 48, 64, 32)           5120      ['bottleneck2_3_reduce_prelu[0
#  nv2D)                                                              ][0]']
#
#  batch_normalization_18 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_3_asym_5x1[0][0]
#  tchNormalization)                                                  ']
#
#  bottleneck2_3_asym_5x1_pre  (None, 48, 64, 32)           32        ['batch_normalization_18[0][0]
#  lu (PReLU)                                                         ']
#
#  bottleneck2_3_asym_1x5 (Co  (None, 48, 64, 32)           5120      ['bottleneck2_3_asym_5x1_prelu
#  nv2D)                                                              [0][0]']
#
#  batch_normalization_19 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_3_asym_1x5[0][0]
#  tchNormalization)                                                  ']
#
#  bottleneck2_3_asym_1x5_pre  (None, 48, 64, 32)           32        ['batch_normalization_19[0][0]
#  lu (PReLU)                                                         ']
#
#  bottleneck2_3_expand (Conv  (None, 48, 64, 128)          4096      ['bottleneck2_3_asym_1x5_prelu
#  2D)                                                                [0][0]']
#
#  bottleneck2_3_expand_bn (B  (None, 48, 64, 128)          512       ['bottleneck2_3_expand[0][0]']
#  atchNormalization)
#
#  bottleneck2_3_drop (Spatia  (None, 48, 64, 128)          0         ['bottleneck2_3_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck2_3_align (Lambd  (None, 48, 64, 128)          0         ['bottleneck2_3_drop[0][0]',
#  a)                                                                  'bottleneck2_2_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck2_3_add (Add)     (None, 48, 64, 128)          0         ['bottleneck2_2_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck2_3_align[0][0]']
#
#  bottleneck2_3_out_prelu (P  (None, 48, 64, 128)          128       ['bottleneck2_3_add[0][0]']
#  ReLU)
#
#  bottleneck2_4_reduce (Conv  (None, 48, 64, 32)           4096      ['bottleneck2_3_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_20 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_4_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck2_4_reduce_prelu  (None, 48, 64, 32)           32        ['batch_normalization_20[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck2_4_conv (Conv2D  (None, 48, 64, 32)           9216      ['bottleneck2_4_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_21 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_4_conv[0][0]']
#  tchNormalization)
#
#  bottleneck2_4_conv_prelu (  (None, 48, 64, 32)           32        ['batch_normalization_21[0][0]
#  PReLU)                                                             ']
#
#  bottleneck2_4_expand (Conv  (None, 48, 64, 128)          4096      ['bottleneck2_4_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck2_4_expand_bn (B  (None, 48, 64, 128)          512       ['bottleneck2_4_expand[0][0]']
#  atchNormalization)
#
#  bottleneck2_4_drop (Spatia  (None, 48, 64, 128)          0         ['bottleneck2_4_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck2_4_align (Lambd  (None, 48, 64, 128)          0         ['bottleneck2_4_drop[0][0]',
#  a)                                                                  'bottleneck2_3_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck2_4_add (Add)     (None, 48, 64, 128)          0         ['bottleneck2_3_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck2_4_align[0][0]']
#
#  bottleneck2_4_out_prelu (P  (None, 48, 64, 128)          128       ['bottleneck2_4_add[0][0]']
#  ReLU)
#
#  bottleneck2_5_reduce (Conv  (None, 48, 64, 32)           4096      ['bottleneck2_4_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_22 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_5_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck2_5_reduce_prelu  (None, 48, 64, 32)           32        ['batch_normalization_22[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck2_5_conv (Conv2D  (None, 48, 64, 32)           9216      ['bottleneck2_5_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_23 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_5_conv[0][0]']
#  tchNormalization)
#
#  bottleneck2_5_conv_prelu (  (None, 48, 64, 32)           32        ['batch_normalization_23[0][0]
#  PReLU)                                                             ']
#
#  bottleneck2_5_expand (Conv  (None, 48, 64, 128)          4096      ['bottleneck2_5_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck2_5_expand_bn (B  (None, 48, 64, 128)          512       ['bottleneck2_5_expand[0][0]']
#  atchNormalization)
#
#  bottleneck2_5_drop (Spatia  (None, 48, 64, 128)          0         ['bottleneck2_5_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck2_5_align (Lambd  (None, 48, 64, 128)          0         ['bottleneck2_5_drop[0][0]',
#  a)                                                                  'bottleneck2_4_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck2_5_add (Add)     (None, 48, 64, 128)          0         ['bottleneck2_4_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck2_5_align[0][0]']
#
#  bottleneck2_5_out_prelu (P  (None, 48, 64, 128)          128       ['bottleneck2_5_add[0][0]']
#  ReLU)
#
#  bottleneck2_6_reduce (Conv  (None, 48, 64, 32)           4096      ['bottleneck2_5_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_24 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_6_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck2_6_reduce_prelu  (None, 48, 64, 32)           32        ['batch_normalization_24[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck2_6_conv (Conv2D  (None, 48, 64, 32)           9216      ['bottleneck2_6_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_25 (Ba  (None, 48, 64, 32)           128       ['bottleneck2_6_conv[0][0]']
#  tchNormalization)
#
#  bottleneck2_6_conv_prelu (  (None, 48, 64, 32)           32        ['batch_normalization_25[0][0]
#  PReLU)                                                             ']
#
#  bottleneck2_6_expand (Conv  (None, 48, 64, 128)          4096      ['bottleneck2_6_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck2_6_expand_bn (B  (None, 48, 64, 128)          512       ['bottleneck2_6_expand[0][0]']
#  atchNormalization)
#
#  bottleneck2_6_drop (Spatia  (None, 48, 64, 128)          0         ['bottleneck2_6_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck2_6_align (Lambd  (None, 48, 64, 128)          0         ['bottleneck2_6_drop[0][0]',
# ...
#   (PReLU)                                                           ']
#
#  bottleneck4_1_conv (Conv2D  (None, 96, 128, 16)          2304      ['bottleneck4_1_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_52 (Ba  (None, 96, 128, 16)          64        ['bottleneck4_1_conv[0][0]']
#  tchNormalization)
#
#  bottleneck4_1_conv_prelu (  (None, 96, 128, 16)          16        ['batch_normalization_52[0][0]
#  PReLU)                                                             ']
#
#  bottleneck4_1_expand (Conv  (None, 96, 128, 64)          1024      ['bottleneck4_1_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck4_1_expand_bn (B  (None, 96, 128, 64)          256       ['bottleneck4_1_expand[0][0]']
#  atchNormalization)
#
#  bottleneck4_1_drop (Spatia  (None, 96, 128, 64)          0         ['bottleneck4_1_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck4_1_align (Lambd  (None, 96, 128, 64)          0         ['bottleneck4_1_drop[0][0]',
#  a)                                                                  'bottleneck4_0_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck4_1_add (Add)     (None, 96, 128, 64)          0         ['bottleneck4_0_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck4_1_align[0][0]']
#
#  bottleneck4_1_out_prelu (P  (None, 96, 128, 64)          64        ['bottleneck4_1_add[0][0]']
#  ReLU)
#
#  bottleneck4_2_reduce (Conv  (None, 96, 128, 16)          1024      ['bottleneck4_1_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_53 (Ba  (None, 96, 128, 16)          64        ['bottleneck4_2_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck4_2_reduce_prelu  (None, 96, 128, 16)          16        ['batch_normalization_53[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck4_2_conv (Conv2D  (None, 96, 128, 16)          2304      ['bottleneck4_2_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_54 (Ba  (None, 96, 128, 16)          64        ['bottleneck4_2_conv[0][0]']
#  tchNormalization)
#
#  bottleneck4_2_conv_prelu (  (None, 96, 128, 16)          16        ['batch_normalization_54[0][0]
#  PReLU)                                                             ']
#
#  bottleneck4_2_expand (Conv  (None, 96, 128, 64)          1024      ['bottleneck4_2_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck4_2_expand_bn (B  (None, 96, 128, 64)          256       ['bottleneck4_2_expand[0][0]']
#  atchNormalization)
#
#  bottleneck4_2_drop (Spatia  (None, 96, 128, 64)          0         ['bottleneck4_2_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck4_2_align (Lambd  (None, 96, 128, 64)          0         ['bottleneck4_2_drop[0][0]',
#  a)                                                                  'bottleneck4_1_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck4_2_add (Add)     (None, 96, 128, 64)          0         ['bottleneck4_1_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck4_2_align[0][0]']
#
#  bottleneck4_2_out_prelu (P  (None, 96, 128, 64)          64        ['bottleneck4_2_add[0][0]']
#  ReLU)
#
#  bottleneck5_0_reduce (Conv  (None, 96, 128, 16)          1024      ['bottleneck4_2_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_55 (Ba  (None, 96, 128, 16)          64        ['bottleneck5_0_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck5_0_reduce_prelu  (None, 96, 128, 16)          16        ['batch_normalization_55[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck5_0_deconv (Conv  (None, 192, 256, 16)         2304      ['bottleneck5_0_reduce_prelu[0
#  2DTranspose)                                                       ][0]']
#
#  batch_normalization_56 (Ba  (None, 192, 256, 16)         64        ['bottleneck5_0_deconv[0][0]']
#  tchNormalization)
#
#  bottleneck5_0_deconv_prelu  (None, 192, 256, 16)         16        ['batch_normalization_56[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck5_0_expand (Conv  (None, 192, 256, 16)         256       ['bottleneck5_0_deconv_prelu[0
#  2D)                                                                ][0]']
#
#  bottleneck5_0_main_up (Con  (None, 192, 256, 16)         9216      ['bottleneck4_2_out_prelu[0][0
#  v2DTranspose)                                                      ]']
#
#  bottleneck5_0_expand_bn (B  (None, 192, 256, 16)         64        ['bottleneck5_0_expand[0][0]']
#  atchNormalization)
#
#  bottleneck5_0_main_up_bn (  (None, 192, 256, 16)         64        ['bottleneck5_0_main_up[0][0]'
#  BatchNormalization)                                                ]
#
#  bottleneck5_0_drop (Spatia  (None, 192, 256, 16)         0         ['bottleneck5_0_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck5_0_align (Lambd  (None, 192, 256, 16)         0         ['bottleneck5_0_drop[0][0]',
#  a)                                                                  'bottleneck5_0_main_up_bn[0][
#                                                                     0]']
#
#  bottleneck5_0_add (Add)     (None, 192, 256, 16)         0         ['bottleneck5_0_main_up_bn[0][
#                                                                     0]',
#                                                                      'bottleneck5_0_align[0][0]']
#
#  bottleneck5_0_out_prelu (P  (None, 192, 256, 16)         16        ['bottleneck5_0_add[0][0]']
#  ReLU)
#
#  bottleneck5_1_reduce (Conv  (None, 192, 256, 16)         256       ['bottleneck5_0_out_prelu[0][0
#  2D)                                                                ]']
#
#  batch_normalization_57 (Ba  (None, 192, 256, 16)         64        ['bottleneck5_1_reduce[0][0]']
#  tchNormalization)
#
#  bottleneck5_1_reduce_prelu  (None, 192, 256, 16)         16        ['batch_normalization_57[0][0]
#   (PReLU)                                                           ']
#
#  bottleneck5_1_conv (Conv2D  (None, 192, 256, 16)         2304      ['bottleneck5_1_reduce_prelu[0
#  )                                                                  ][0]']
#
#  batch_normalization_58 (Ba  (None, 192, 256, 16)         64        ['bottleneck5_1_conv[0][0]']
#  tchNormalization)
#
#  bottleneck5_1_conv_prelu (  (None, 192, 256, 16)         16        ['batch_normalization_58[0][0]
#  PReLU)                                                             ']
#
#  bottleneck5_1_expand (Conv  (None, 192, 256, 16)         256       ['bottleneck5_1_conv_prelu[0][
#  2D)                                                                0]']
#
#  bottleneck5_1_expand_bn (B  (None, 192, 256, 16)         64        ['bottleneck5_1_expand[0][0]']
#  atchNormalization)
#
#  bottleneck5_1_drop (Spatia  (None, 192, 256, 16)         0         ['bottleneck5_1_expand_bn[0][0
#  lDropout2D)                                                        ]']
#
#  bottleneck5_1_align (Lambd  (None, 192, 256, 16)         0         ['bottleneck5_1_drop[0][0]',
#  a)                                                                  'bottleneck5_0_out_prelu[0][0
#                                                                     ]']
#
#  bottleneck5_1_add (Add)     (None, 192, 256, 16)         0         ['bottleneck5_0_out_prelu[0][0
#                                                                     ]',
#                                                                      'bottleneck5_1_align[0][0]']
#
#  bottleneck5_1_out_prelu (P  (None, 192, 256, 16)         16        ['bottleneck5_1_add[0][0]']
#  ReLU)
#
#  fullconv (Conv2DTranspose)  (None, 384, 512, 2)          290       ['bottleneck5_1_out_prelu[0][0
#                                                                     ]']
#
#  pred (Activation)           (None, 384, 512, 2)          0         ['fullconv[0][0]']
#
#  force_resize (Lambda)       (None, 384, 508, 2)          0         ['pred[0][0]']
#
# ==================================================================================================
# Total params: 454690 (1.73 MB)
# Trainable params: 445608 (1.70 MB)
# Non-trainable params: 9082 (35.48 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

class MeanIoU(tf.keras.metrics.MeanIoU):
    def __call__(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().__call__(y_true, y_pred, sample_weight=sample_weight)

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')
train_iou = MeanIoU(num_classes=2, name='train_iou')

val_loss = tf.keras.metrics.Mean(name='val_loss')
val_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='val_accuracy')
val_iou = MeanIoU(num_classes=2, name='val_iou')

# ===============================
# 3. 单步训练与验证
# ===============================
@tf.function
def train_step(images, labels):
    with tf.GradientTape() as tape:
        predictions = model(images, training=True)
        loss = loss_object(labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    train_loss(loss)
    train_accuracy(labels, predictions)
    train_iou(labels, predictions)

@tf.function
def val_step(images, labels):
    predictions = model(images, training=False)
    loss = loss_object(labels, predictions)

    val_loss(loss)
    val_accuracy(labels, predictions)
    val_iou(labels, predictions)

# ===============================
# 4. 训练循环
# ===============================
EPOCHS = 50
train_loss_list, train_acc_list, train_iou_list = [], [], []
val_loss_list, val_acc_list, val_iou_list = [], [], []

for epoch in range(EPOCHS):
    train_loss.reset_state()
    train_accuracy.reset_state()
    train_iou.reset_state()
    val_loss.reset_state()
    val_accuracy.reset_state()
    val_iou.reset_state()

    for images, labels in dataset_train:
        train_step(images, labels)

    for images, labels in dataset_val:
        val_step(images, labels)

    train_loss_list.append(train_loss.result().numpy())
    train_acc_list.append(train_accuracy.result().numpy())
    train_iou_list.append(train_iou.result().numpy())
    val_loss_list.append(val_loss.result().numpy())
    val_acc_list.append(val_accuracy.result().numpy())
    val_iou_list.append(val_iou.result().numpy())

    print(f"Epoch {epoch+1:02d}: "
          f"Loss={train_loss.result():.4f}, Acc={train_accuracy.result():.4f}, IoU={train_iou.result():.4f} | "
          f"Val Loss={val_loss.result():.4f}, Val Acc={val_accuracy.result():.4f}, Val IoU={val_iou.result():.4f}")
# Out:
# 2025-08-11 03:28:54.511480: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inENet/bottleneck1_0_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-08-11 03:28:57.656866: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-08-11 03:28:58.327871: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-08-11 03:29:00.542091: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f6e87dc5b10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-08-11 03:29:00.542154: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-08-11 03:29:00.546382: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-08-11 03:29:00.681168: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-08-11 03:30:00.836895: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inENet/bottleneck1_0_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# Epoch 01: Loss=0.5486, Acc=0.7966, IoU=0.4927 | Val Loss=0.5381, Val Acc=0.8633, Val IoU=0.4369
# Epoch 02: Loss=0.4377, Acc=0.9296, IoU=0.7401 | Val Loss=0.4460, Val Acc=0.9069, Val IoU=0.6061
# Epoch 03: Loss=0.3928, Acc=0.9524, IoU=0.8136 | Val Loss=0.3855, Val Acc=0.9524, Val IoU=0.7978
# Epoch 04: Loss=0.3712, Acc=0.9608, IoU=0.8427 | Val Loss=0.3651, Val Acc=0.9625, Val IoU=0.8415
# Epoch 05: Loss=0.3586, Acc=0.9665, IoU=0.8635 | Val Loss=0.3547, Val Acc=0.9677, Val IoU=0.8712
# Epoch 06: Loss=0.3507, Acc=0.9704, IoU=0.8777 | Val Loss=0.3471, Val Acc=0.9725, Val IoU=0.8848
# Epoch 07: Loss=0.3452, Acc=0.9734, IoU=0.8893 | Val Loss=0.3444, Val Acc=0.9731, Val IoU=0.8873
# Epoch 08: Loss=0.3421, Acc=0.9749, IoU=0.8952 | Val Loss=0.3404, Val Acc=0.9759, Val IoU=0.8994
# Epoch 09: Loss=0.3392, Acc=0.9767, IoU=0.9022 | Val Loss=0.3374, Val Acc=0.9780, Val IoU=0.9070
# Epoch 10: Loss=0.3367, Acc=0.9785, IoU=0.9091 | Val Loss=0.3363, Val Acc=0.9786, Val IoU=0.9093
# Epoch 11: Loss=0.3353, Acc=0.9793, IoU=0.9126 | Val Loss=0.3349, Val Acc=0.9795, Val IoU=0.9132
# Epoch 12: Loss=0.3341, Acc=0.9801, IoU=0.9157 | Val Loss=0.3358, Val Acc=0.9781, Val IoU=0.9092
# Epoch 13: Loss=0.3328, Acc=0.9811, IoU=0.9195 | Val Loss=0.3322, Val Acc=0.9816, Val IoU=0.9207
# Epoch 14: Loss=0.3318, Acc=0.9818, IoU=0.9225 | Val Loss=0.3314, Val Acc=0.9822, Val IoU=0.9244
# Epoch 15: Loss=0.3310, Acc=0.9824, IoU=0.9249 | Val Loss=0.3307, Val Acc=0.9828, Val IoU=0.9272
# Epoch 16: Loss=0.3302, Acc=0.9831, IoU=0.9276 | Val Loss=0.3303, Val Acc=0.9829, Val IoU=0.9273
# Epoch 17: Loss=0.3296, Acc=0.9836, IoU=0.9295 | Val Loss=0.3296, Val Acc=0.9836, Val IoU=0.9290
# Epoch 18: Loss=0.3290, Acc=0.9841, IoU=0.9317 | Val Loss=0.3293, Val Acc=0.9838, Val IoU=0.9303
# Epoch 19: Loss=0.3285, Acc=0.9845, IoU=0.9334 | Val Loss=0.3297, Val Acc=0.9833, Val IoU=0.9270
# Epoch 20: Loss=0.3281, Acc=0.9848, IoU=0.9348 | Val Loss=0.3282, Val Acc=0.9848, Val IoU=0.9341
# Epoch 21: Loss=0.3277, Acc=0.9852, IoU=0.9364 | Val Loss=0.3287, Val Acc=0.9842, Val IoU=0.9310
# Epoch 22: Loss=0.3274, Acc=0.9854, IoU=0.9372 | Val Loss=0.3278, Val Acc=0.9851, Val IoU=0.9364
# Epoch 23: Loss=0.3269, Acc=0.9859, IoU=0.9391 | Val Loss=0.3289, Val Acc=0.9839, Val IoU=0.9294
# Epoch 24: Loss=0.3266, Acc=0.9862, IoU=0.9404 | Val Loss=0.3278, Val Acc=0.9850, Val IoU=0.9344
# Epoch 25: Loss=0.3264, Acc=0.9864, IoU=0.9410 | Val Loss=0.3266, Val Acc=0.9863, Val IoU=0.9407
# Epoch 26: Loss=0.3260, Acc=0.9868, IoU=0.9430 | Val Loss=0.3263, Val Acc=0.9865, Val IoU=0.9414
# Epoch 27: Loss=0.3258, Acc=0.9869, IoU=0.9434 | Val Loss=0.3263, Val Acc=0.9865, Val IoU=0.9416
# Epoch 28: Loss=0.3254, Acc=0.9874, IoU=0.9452 | Val Loss=0.3261, Val Acc=0.9867, Val IoU=0.9421
# Epoch 29: Loss=0.3253, Acc=0.9875, IoU=0.9456 | Val Loss=0.3255, Val Acc=0.9873, Val IoU=0.9450
# Epoch 30: Loss=0.3251, Acc=0.9876, IoU=0.9461 | Val Loss=0.3264, Val Acc=0.9863, Val IoU=0.9403
# Epoch 31: Loss=0.3249, Acc=0.9878, IoU=0.9472 | Val Loss=0.3254, Val Acc=0.9874, Val IoU=0.9451
# Epoch 32: Loss=0.3246, Acc=0.9881, IoU=0.9482 | Val Loss=0.3251, Val Acc=0.9877, Val IoU=0.9467
# Epoch 33: Loss=0.3244, Acc=0.9883, IoU=0.9492 | Val Loss=0.3250, Val Acc=0.9877, Val IoU=0.9466
# Epoch 34: Loss=0.3242, Acc=0.9885, IoU=0.9500 | Val Loss=0.3262, Val Acc=0.9865, Val IoU=0.9420
# Epoch 35: Loss=0.3241, Acc=0.9887, IoU=0.9506 | Val Loss=0.3253, Val Acc=0.9875, Val IoU=0.9459
# Epoch 36: Loss=0.3238, Acc=0.9889, IoU=0.9517 | Val Loss=0.3249, Val Acc=0.9879, Val IoU=0.9475
# Epoch 37: Loss=0.3237, Acc=0.9891, IoU=0.9523 | Val Loss=0.3245, Val Acc=0.9883, Val IoU=0.9493
# Epoch 38: Loss=0.3239, Acc=0.9888, IoU=0.9510 | Val Loss=0.3248, Val Acc=0.9880, Val IoU=0.9476
# Epoch 39: Loss=0.3235, Acc=0.9892, IoU=0.9529 | Val Loss=0.3253, Val Acc=0.9875, Val IoU=0.9459
# Epoch 40: Loss=0.3234, Acc=0.9894, IoU=0.9536 | Val Loss=0.3248, Val Acc=0.9879, Val IoU=0.9478
# Epoch 41: Loss=0.3232, Acc=0.9895, IoU=0.9542 | Val Loss=0.3242, Val Acc=0.9886, Val IoU=0.9505
# Epoch 42: Loss=0.3231, Acc=0.9897, IoU=0.9549 | Val Loss=0.3243, Val Acc=0.9885, Val IoU=0.9498
# Epoch 43: Loss=0.3229, Acc=0.9898, IoU=0.9556 | Val Loss=0.3241, Val Acc=0.9887, Val IoU=0.9510
# Epoch 44: Loss=0.3228, Acc=0.9900, IoU=0.9561 | Val Loss=0.3238, Val Acc=0.9890, Val IoU=0.9522
# Epoch 45: Loss=0.3227, Acc=0.9901, IoU=0.9567 | Val Loss=0.3237, Val Acc=0.9891, Val IoU=0.9526
# Epoch 46: Loss=0.3226, Acc=0.9902, IoU=0.9571 | Val Loss=0.3239, Val Acc=0.9889, Val IoU=0.9520
# Epoch 47: Loss=0.3224, Acc=0.9904, IoU=0.9578 | Val Loss=0.3234, Val Acc=0.9894, Val IoU=0.9539
# Epoch 48: Loss=0.3222, Acc=0.9905, IoU=0.9585 | Val Loss=0.3233, Val Acc=0.9895, Val IoU=0.9540
# Epoch 49: Loss=0.3222, Acc=0.9906, IoU=0.9588 | Val Loss=0.3231, Val Acc=0.9897, Val IoU=0.9551
# Epoch 50: Loss=0.3222, Acc=0.9906, IoU=0.9588 | Val Loss=0.3233, Val Acc=0.9895, Val IoU=0.9544

# %%
# ========= 训练曲线可视化 ========= #

epochs = range(1, EPOCHS + 1)
plt.figure(figsize=(18, 5))

# Loss
plt.subplot(1, 3, 1)
plt.plot(epochs, train_loss_list, label='Train Loss')
plt.plot(epochs, val_loss_list, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()

# Accuracy
plt.subplot(1, 3, 2)
plt.plot(epochs, train_acc_list, label='Train Accuracy')
plt.plot(epochs, val_acc_list, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()

# IoU
plt.subplot(1, 3, 3)
plt.plot(epochs, train_iou_list, label='Train IoU')
plt.plot(epochs, val_iou_list, label='Val IoU')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.title('Training & Validation IoU')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save_weights('my_model_weights.weights.h5')
model.save('my_model_full.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /environment/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall
import pickle

# with open("weights_tf10_compatible.pkl", "rb") as f:
#     weights = pickle.load(f)
# models.set_weights(weights)
model.load_weights('my_model_weights.weights.h5')


miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()


cmap = ListedColormap(['black', 'green', 'red'])

#  每轮展示多少图像
num = 10

#  从验证集取一个 batch
for image, mask in dataset_test.take(1):
    # 模型预测（logits -> 类别索引）
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1) for broadcasting

    # 可视化结果
    fig = plt.figure(figsize=(15, num * 5))

    for i in range(num):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

        plt.subplot(num, 4, i * 4 + 1)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(image[i]))
        plt.title("Input Image")

        plt.subplot(num, 4, i * 4 + 2)
        plt.imshow(true_mask, cmap=cmap, interpolation='nearest')
        plt.title("True Mask")

        plt.subplot(num, 4, i * 4 + 3)
        plt.imshow(pred, cmap=cmap, interpolation='nearest')
        plt.title("Predicted Mask")

        plt.subplot(num, 4, i * 4 + 4)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(image[i]), alpha=0.7)
        plt.imshow(pred, cmap=cmap, alpha=0.3, interpolation='nearest')
        plt.title("Overlay")

    plt.tight_layout()
    plt.show()

print(" Evaluation Metrics")
print("Mean IoU   :", miou_metric.result().numpy())
print("Accuracy   :", accuracy_metric.result().numpy())
print("Precision  :", precision_metric.result().numpy())
print("Recall     :", recall_metric.result().numpy())
# Out:
# 1/1 [==============================] - 1s 1s/step
#  Evaluation Metrics
# Mean IoU   : 0.9464338
# Accuracy   : 0.9878686
# Precision  : 0.94363445
# Recall     : 0.95852715

# %%
import tensorflow as tf
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall

miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()

cmap = ListedColormap(['black', 'green', 'red'])

for image, mask in dataset_test:
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1)

    for i in range(image.shape[0]):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

print("\n Evaluation Metrics on Test Set")
print("Mean IoU   :", round(miou_metric.result().numpy(), 4))
print("Accuracy   :", round(accuracy_metric.result().numpy(), 4))
print("Precision  :", round(precision_metric.result().numpy(), 4))
print("Recall     :", round(recall_metric.result().numpy(), 4))
# Out:
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 1s 598ms/step
#
#  Evaluation Metrics on Test Set
# Mean IoU   : 0.9515
# Accuracy   : 0.9887
# Precision  : 0.9513
# Recall     : 0.961

# %%
import tensorflow as tf
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall
import numpy as np

# with open("weights_tf10_compatible.pkl", "rb") as f:
#     weights = pickle.load(f)
model.load_weights('my_model_weights.weights.h5')

miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()

num_classes = 2
confusion_matrix = np.zeros((num_classes, num_classes), dtype=np.int64)

cmap = ListedColormap(['black', 'green', 'red'])

for image, mask in dataset_test:
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1)

    for i in range(image.shape[0]):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

        y_true = tf.reshape(true_mask, [-1])
        y_pred = tf.reshape(pred, [-1])
        cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=num_classes).numpy()
        confusion_matrix += cm

dice_per_class = []
for i in range(num_classes):
    TP = confusion_matrix[i, i]
    FP = np.sum(confusion_matrix[:, i]) - TP
    FN = np.sum(confusion_matrix[i, :]) - TP
    denom = 2 * TP + FP + FN
    dice = 2 * TP / denom if denom > 0 else 0.0
    dice_per_class.append(dice)

mean_dice = np.mean(dice_per_class)

print("\n Evaluation Metrics on Test Set")
print("Mean IoU   :", round(miou_metric.result().numpy(), 4))
print("Accuracy   :", round(accuracy_metric.result().numpy(), 4))
print("Precision  :", round(precision_metric.result().numpy(), 4))
print("Recall     :", round(recall_metric.result().numpy(), 4))
print("Dice Coef. :", [f"Class {i}: {round(d, 4)}" for i, d in enumerate(dice_per_class)])
print("Mean Dice  :", round(mean_dice, 4))
# Out:
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
#
#  Evaluation Metrics on Test Set
# Mean IoU   : 0.9515
# Accuracy   : 0.9887
# Precision  : 0.9513
# Recall     : 0.961
# Dice Coef. : ['Class 0: 0.9935', 'Class 1: 0.9561']
# Mean Dice  : 0.9748
