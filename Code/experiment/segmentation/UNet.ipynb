# %%
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
from data_preprocessing import create_segmentation_datasets
# Out:
# 2025-08-11 03:39:13.117754: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-11 03:39:13.857980: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
image_dir = '/home/featurize/data/segmentation_dataset/images'
mask_dir = '/home/featurize/data/segmentation_dataset/masks'

dataset_train, dataset_val, dataset_test = create_segmentation_datasets(image_dir=image_dir, mask_dir=mask_dir, batch_size=24, val_split=0.2, test_split=0.1)

for imgs, masks in dataset_train.take(1):
    print('Train batch images:', imgs.shape, 'masks:', masks.shape)
for imgs, masks in dataset_val.take(1):
    print('Val batch images:', imgs.shape, 'masks:', masks.shape)
for imgs, masks in dataset_test.take(1):
    print('Test batch images:', imgs.shape, 'masks:', masks.shape)
# Out:
# Training samples: 4634, validation samples: 1324, test samples: 662
# 2025-08-11 03:39:14.706914: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:39:14.716002: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:39:14.716314: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:39:14.719453: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:39:14.719764: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:39:14.720036: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:39:15.173486: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:39:15.173723: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:39:15.173883: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-11 03:39:15.173997: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-08-11 03:39:15.174030: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46692 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:10:00.0, compute capability: 8.6
# Train batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)
# Val batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)
# Test batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)

# %%
# import tensorflow as tf
# import numpy as np
# from collections import Counter

# def count_classes_in_dataset(dataset):
#     total_counter = Counter()

#     for batch in dataset:
#         images, masks = batch
#         flat_masks = tf.reshape(masks, [-1])
#         result = tf.unique_with_counts(flat_masks)
#         unique_vals = result.y
#         counts = result.count

#         for val, count in zip(unique_vals.numpy(), counts.numpy()):
#             total_counter[int(val)] += int(count)

#     print("\n Dataset 中的类别总分布：")
#     for cls in sorted(total_counter.keys()):
#         print(f"类 {cls}: {total_counter[cls]} 像素")

#     return total_counter

# # 示例调用
# count_classes_in_dataset(dataset_train)

# %%
import matplotlib.pyplot as plt
import numpy as np

for img_batch, mask_batch in dataset_train.take(1):
    img = img_batch[0].numpy()
    mask = mask_batch[0].numpy()

    # 1. 将图像从 [-1, 1] 转回 [0, 1] 浮点图像
    img_display = (img + 1.0) / 2.0
    img_display = np.clip(img_display, 0.0, 1.0)

    # 2. 将 mask squeeze，转换为 uint8，用于灰度显示
    mask_display = np.squeeze(mask).astype(np.uint8)

    # 可视化
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(img_display, cmap='gray', vmin=0.0, vmax=1.0)  # 显式指定范围
    plt.axis('off')
    plt.title("Augmented Image")

    plt.subplot(1, 2, 2)
    plt.imshow(mask_display, cmap='gray', vmin=0, vmax=1)  # 确保 0=黑，1=白
    plt.axis('off')
    plt.title("Mask")

    plt.show()

# %%
from model_test import model

# %%
model = model(img_height=384, img_width=508, classes=2)
model.summary()
# Out:
# *** Output Shape: (None, 384, 508, 2) ***
# Model: "UNet_Bilinear"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 384, 508, 3)]        0         []
#
#  enc1_1_conv (Conv2D)        (None, 384, 508, 64)         1728      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 384, 508, 64)         256       ['enc1_1_conv[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 384, 508, 64)         0         ['batch_normalization[0][0]']
#
#  enc1_2_conv (Conv2D)        (None, 384, 508, 64)         36864     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 384, 508, 64)         256       ['enc1_2_conv[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 384, 508, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  pool1 (MaxPooling2D)        (None, 192, 254, 64)         0         ['activation_1[0][0]']
#
#  enc2_1_conv (Conv2D)        (None, 192, 254, 128)        73728     ['pool1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 192, 254, 128)        512       ['enc2_1_conv[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 192, 254, 128)        0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  enc2_2_conv (Conv2D)        (None, 192, 254, 128)        147456    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 192, 254, 128)        512       ['enc2_2_conv[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 192, 254, 128)        0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  pool2 (MaxPooling2D)        (None, 96, 127, 128)         0         ['activation_3[0][0]']
#
#  enc3_1_conv (Conv2D)        (None, 96, 127, 256)         294912    ['pool2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 96, 127, 256)         1024      ['enc3_1_conv[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 96, 127, 256)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  enc3_2_conv (Conv2D)        (None, 96, 127, 256)         589824    ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 96, 127, 256)         1024      ['enc3_2_conv[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 96, 127, 256)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  pool3 (MaxPooling2D)        (None, 48, 64, 256)          0         ['activation_5[0][0]']
#
#  enc4_1_conv (Conv2D)        (None, 48, 64, 512)          1179648   ['pool3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 48, 64, 512)          2048      ['enc4_1_conv[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 48, 64, 512)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  enc4_2_conv (Conv2D)        (None, 48, 64, 512)          2359296   ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 48, 64, 512)          2048      ['enc4_2_conv[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 48, 64, 512)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  pool4 (MaxPooling2D)        (None, 24, 32, 512)          0         ['activation_7[0][0]']
#
#  bottleneck_1_conv (Conv2D)  (None, 24, 32, 1024)         4718592   ['pool4[0][0]']
#
#  batch_normalization_8 (Bat  (None, 24, 32, 1024)         4096      ['bottleneck_1_conv[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 24, 32, 1024)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  bottleneck_2_conv (Conv2D)  (None, 24, 32, 1024)         9437184   ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 24, 32, 1024)         4096      ['bottleneck_2_conv[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 24, 32, 1024)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  up4 (UpSampling2D)          (None, 48, 64, 1024)         0         ['activation_9[0][0]']
#
#  up4_proj_conv (Conv2D)      (None, 48, 64, 512)          4718592   ['up4[0][0]']
#
#  batch_normalization_10 (Ba  (None, 48, 64, 512)          2048      ['up4_proj_conv[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 48, 64, 512)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  align_u4_to_c4 (Lambda)     (None, 48, 64, 512)          0         ['activation_10[0][0]',
#                                                                      'activation_7[0][0]']
#
#  merge4 (Concatenate)        (None, 48, 64, 1024)         0         ['align_u4_to_c4[0][0]',
#                                                                      'activation_7[0][0]']
#
#  dec4_1_conv (Conv2D)        (None, 48, 64, 512)          4718592   ['merge4[0][0]']
#
#  batch_normalization_11 (Ba  (None, 48, 64, 512)          2048      ['dec4_1_conv[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 48, 64, 512)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dec4_2_conv (Conv2D)        (None, 48, 64, 512)          2359296   ['activation_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 48, 64, 512)          2048      ['dec4_2_conv[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 48, 64, 512)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  up3 (UpSampling2D)          (None, 96, 128, 512)         0         ['activation_12[0][0]']
#
#  up3_proj_conv (Conv2D)      (None, 96, 128, 256)         1179648   ['up3[0][0]']
#
#  batch_normalization_13 (Ba  (None, 96, 128, 256)         1024      ['up3_proj_conv[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 96, 128, 256)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  align_u3_to_c3 (Lambda)     (None, 96, 127, 256)         0         ['activation_13[0][0]',
#                                                                      'activation_5[0][0]']
#
#  merge3 (Concatenate)        (None, 96, 127, 512)         0         ['align_u3_to_c3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  dec3_1_conv (Conv2D)        (None, 96, 127, 256)         1179648   ['merge3[0][0]']
#
#  batch_normalization_14 (Ba  (None, 96, 127, 256)         1024      ['dec3_1_conv[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 96, 127, 256)         0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  dec3_2_conv (Conv2D)        (None, 96, 127, 256)         589824    ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 96, 127, 256)         1024      ['dec3_2_conv[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 96, 127, 256)         0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  up2 (UpSampling2D)          (None, 192, 254, 256)        0         ['activation_15[0][0]']
#
#  up2_proj_conv (Conv2D)      (None, 192, 254, 128)        294912    ['up2[0][0]']
#
#  batch_normalization_16 (Ba  (None, 192, 254, 128)        512       ['up2_proj_conv[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 192, 254, 128)        0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  align_u2_to_c2 (Lambda)     (None, 192, 254, 128)        0         ['activation_16[0][0]',
#                                                                      'activation_3[0][0]']
#
#  merge2 (Concatenate)        (None, 192, 254, 256)        0         ['align_u2_to_c2[0][0]',
#                                                                      'activation_3[0][0]']
#
#  dec2_1_conv (Conv2D)        (None, 192, 254, 128)        294912    ['merge2[0][0]']
#
#  batch_normalization_17 (Ba  (None, 192, 254, 128)        512       ['dec2_1_conv[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 192, 254, 128)        0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  dec2_2_conv (Conv2D)        (None, 192, 254, 128)        147456    ['activation_17[0][0]']
#
#  batch_normalization_18 (Ba  (None, 192, 254, 128)        512       ['dec2_2_conv[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 192, 254, 128)        0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  up1 (UpSampling2D)          (None, 384, 508, 128)        0         ['activation_18[0][0]']
#
#  up1_proj_conv (Conv2D)      (None, 384, 508, 64)         73728     ['up1[0][0]']
#
#  batch_normalization_19 (Ba  (None, 384, 508, 64)         256       ['up1_proj_conv[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 384, 508, 64)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  align_u1_to_c1 (Lambda)     (None, 384, 508, 64)         0         ['activation_19[0][0]',
#                                                                      'activation_1[0][0]']
#
#  merge1 (Concatenate)        (None, 384, 508, 128)        0         ['align_u1_to_c1[0][0]',
#                                                                      'activation_1[0][0]']
#
#  dec1_1_conv (Conv2D)        (None, 384, 508, 64)         73728     ['merge1[0][0]']
#
#  batch_normalization_20 (Ba  (None, 384, 508, 64)         256       ['dec1_1_conv[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 384, 508, 64)         0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  dec1_2_conv (Conv2D)        (None, 384, 508, 64)         36864     ['activation_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 384, 508, 64)         256       ['dec1_2_conv[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 384, 508, 64)         0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  cls (Conv2D)                (None, 384, 508, 2)          130       ['activation_21[0][0]']
#
#  pred (Activation)           (None, 384, 508, 2)          0         ['cls[0][0]']
#
#  force_resize (Lambda)       (None, 384, 508, 2)          0         ['pred[0][0]']
#
# ==================================================================================================
# Total params: 34533954 (131.74 MB)
# Trainable params: 34520258 (131.68 MB)
# Non-trainable params: 13696 (53.50 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

class MeanIoU(tf.keras.metrics.MeanIoU):
    def __call__(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().__call__(y_true, y_pred, sample_weight=sample_weight)

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')
train_iou = MeanIoU(num_classes=2, name='train_iou')

val_loss = tf.keras.metrics.Mean(name='val_loss')
val_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='val_accuracy')
val_iou = MeanIoU(num_classes=2, name='val_iou')

# ===============================
# 3. 单步训练与验证
# ===============================
@tf.function
def train_step(images, labels):
    with tf.GradientTape() as tape:
        predictions = model(images, training=True)
        loss = loss_object(labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    train_loss(loss)
    train_accuracy(labels, predictions)
    train_iou(labels, predictions)

@tf.function
def val_step(images, labels):
    predictions = model(images, training=False)
    loss = loss_object(labels, predictions)

    val_loss(loss)
    val_accuracy(labels, predictions)
    val_iou(labels, predictions)

# ===============================
# 4. 训练循环
# ===============================
EPOCHS = 50
train_loss_list, train_acc_list, train_iou_list = [], [], []
val_loss_list, val_acc_list, val_iou_list = [], [], []

for epoch in range(EPOCHS):
    train_loss.reset_state()
    train_accuracy.reset_state()
    train_iou.reset_state()
    val_loss.reset_state()
    val_accuracy.reset_state()
    val_iou.reset_state()

    for images, labels in dataset_train:
        train_step(images, labels)

    for images, labels in dataset_val:
        val_step(images, labels)

    train_loss_list.append(train_loss.result().numpy())
    train_acc_list.append(train_accuracy.result().numpy())
    train_iou_list.append(train_iou.result().numpy())
    val_loss_list.append(val_loss.result().numpy())
    val_acc_list.append(val_accuracy.result().numpy())
    val_iou_list.append(val_iou.result().numpy())

    print(f"Epoch {epoch+1:02d}: "
          f"Loss={train_loss.result():.4f}, Acc={train_accuracy.result():.4f}, IoU={train_iou.result():.4f} | "
          f"Val Loss={val_loss.result():.4f}, Val Acc={val_accuracy.result():.4f}, Val IoU={val_iou.result():.4f}")
# Out:
# 2025-08-11 03:39:22.188264: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-08-11 03:39:57.165946: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f1d2e32d780 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-08-11 03:39:57.166007: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-08-11 03:39:57.171145: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-08-11 03:39:57.300244: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-08-11 03:43:51.620530: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch 01: Loss=0.3947, Acc=0.9324, IoU=0.7475 | Val Loss=0.4161, Val Acc=0.9039, Val IoU=0.5702
# Epoch 02: Loss=0.3545, Acc=0.9641, IoU=0.8534 | Val Loss=0.3636, Val Acc=0.9527, Val IoU=0.7942
# Epoch 03: Loss=0.3440, Acc=0.9727, IoU=0.8861 | Val Loss=0.3427, Val Acc=0.9728, Val IoU=0.8818
# Epoch 04: Loss=0.3389, Acc=0.9765, IoU=0.9012 | Val Loss=0.3405, Val Acc=0.9739, Val IoU=0.8863
# Epoch 05: Loss=0.3354, Acc=0.9791, IoU=0.9115 | Val Loss=0.3379, Val Acc=0.9758, Val IoU=0.8929
# Epoch 06: Loss=0.3321, Acc=0.9821, IoU=0.9237 | Val Loss=0.3350, Val Acc=0.9786, Val IoU=0.9064
# Epoch 07: Loss=0.3314, Acc=0.9823, IoU=0.9246 | Val Loss=0.3324, Val Acc=0.9809, Val IoU=0.9196
# Epoch 08: Loss=0.3295, Acc=0.9840, IoU=0.9314 | Val Loss=0.3317, Val Acc=0.9815, Val IoU=0.9204
# Epoch 09: Loss=0.3280, Acc=0.9853, IoU=0.9368 | Val Loss=0.3302, Val Acc=0.9829, Val IoU=0.9251
# Epoch 10: Loss=0.3272, Acc=0.9860, IoU=0.9398 | Val Loss=0.3287, Val Acc=0.9844, Val IoU=0.9325
# Epoch 11: Loss=0.3264, Acc=0.9868, IoU=0.9428 | Val Loss=0.3293, Val Acc=0.9836, Val IoU=0.9274
# Epoch 12: Loss=0.3256, Acc=0.9875, IoU=0.9457 | Val Loss=0.3305, Val Acc=0.9822, Val IoU=0.9224
# Epoch 13: Loss=0.3260, Acc=0.9870, IoU=0.9438 | Val Loss=0.3336, Val Acc=0.9789, Val IoU=0.9065
# Epoch 14: Loss=0.3245, Acc=0.9885, IoU=0.9501 | Val Loss=0.3289, Val Acc=0.9838, Val IoU=0.9295
# Epoch 15: Loss=0.3237, Acc=0.9892, IoU=0.9532 | Val Loss=0.3415, Val Acc=0.9706, Val IoU=0.8688
# Epoch 16: Loss=0.3229, Acc=0.9901, IoU=0.9569 | Val Loss=0.3263, Val Acc=0.9864, Val IoU=0.9400
# Epoch 17: Loss=0.3224, Acc=0.9906, IoU=0.9590 | Val Loss=0.3309, Val Acc=0.9815, Val IoU=0.9189
# Epoch 18: Loss=0.3221, Acc=0.9909, IoU=0.9602 | Val Loss=0.3273, Val Acc=0.9853, Val IoU=0.9355
# Epoch 19: Loss=0.3221, Acc=0.9908, IoU=0.9599 | Val Loss=0.3268, Val Acc=0.9858, Val IoU=0.9375
# Epoch 20: Loss=0.3213, Acc=0.9916, IoU=0.9634 | Val Loss=0.3250, Val Acc=0.9877, Val IoU=0.9461
# Epoch 21: Loss=0.3208, Acc=0.9922, IoU=0.9657 | Val Loss=0.3292, Val Acc=0.9833, Val IoU=0.9264
# Epoch 22: Loss=0.3210, Acc=0.9920, IoU=0.9648 | Val Loss=0.3270, Val Acc=0.9856, Val IoU=0.9372
# Epoch 23: Loss=0.3203, Acc=0.9926, IoU=0.9676 | Val Loss=0.3239, Val Acc=0.9889, Val IoU=0.9511
# Epoch 24: Loss=0.3194, Acc=0.9936, IoU=0.9720 | Val Loss=0.3247, Val Acc=0.9880, Val IoU=0.9472
# Epoch 25: Loss=0.3194, Acc=0.9936, IoU=0.9718 | Val Loss=0.3230, Val Acc=0.9898, Val IoU=0.9549
# Epoch 26: Loss=0.3192, Acc=0.9938, IoU=0.9727 | Val Loss=0.3244, Val Acc=0.9883, Val IoU=0.9485
# Epoch 27: Loss=0.3193, Acc=0.9937, IoU=0.9722 | Val Loss=0.3257, Val Acc=0.9870, Val IoU=0.9426
# Epoch 28: Loss=0.3191, Acc=0.9939, IoU=0.9732 | Val Loss=0.3233, Val Acc=0.9894, Val IoU=0.9534
# Epoch 29: Loss=0.3193, Acc=0.9937, IoU=0.9721 | Val Loss=0.3357, Val Acc=0.9765, Val IoU=0.8971
# Epoch 30: Loss=0.3205, Acc=0.9923, IoU=0.9663 | Val Loss=0.3254, Val Acc=0.9872, Val IoU=0.9448
# Epoch 31: Loss=0.3187, Acc=0.9943, IoU=0.9746 | Val Loss=0.3243, Val Acc=0.9884, Val IoU=0.9487
# Epoch 32: Loss=0.3180, Acc=0.9950, IoU=0.9778 | Val Loss=0.3231, Val Acc=0.9897, Val IoU=0.9543
# Epoch 33: Loss=0.3177, Acc=0.9953, IoU=0.9793 | Val Loss=0.3230, Val Acc=0.9898, Val IoU=0.9550
# Epoch 34: Loss=0.3178, Acc=0.9952, IoU=0.9787 | Val Loss=0.3225, Val Acc=0.9903, Val IoU=0.9572
# Epoch 35: Loss=0.3174, Acc=0.9956, IoU=0.9805 | Val Loss=0.3281, Val Acc=0.9845, Val IoU=0.9313
# Epoch 36: Loss=0.3175, Acc=0.9956, IoU=0.9803 | Val Loss=0.3221, Val Acc=0.9907, Val IoU=0.9591
# Epoch 37: Loss=0.3174, Acc=0.9957, IoU=0.9807 | Val Loss=0.3243, Val Acc=0.9885, Val IoU=0.9487
# Epoch 38: Loss=0.3176, Acc=0.9954, IoU=0.9796 | Val Loss=0.3279, Val Acc=0.9847, Val IoU=0.9333
# Epoch 39: Loss=0.3196, Acc=0.9933, IoU=0.9705 | Val Loss=0.3411, Val Acc=0.9711, Val IoU=0.8718
# Epoch 40: Loss=0.3182, Acc=0.9948, IoU=0.9771 | Val Loss=0.3232, Val Acc=0.9896, Val IoU=0.9541
# Epoch 41: Loss=0.3171, Acc=0.9960, IoU=0.9820 | Val Loss=0.3213, Val Acc=0.9915, Val IoU=0.9623
# Epoch 42: Loss=0.3170, Acc=0.9960, IoU=0.9824 | Val Loss=0.3251, Val Acc=0.9876, Val IoU=0.9451
# Epoch 43: Loss=0.3169, Acc=0.9962, IoU=0.9830 | Val Loss=0.3209, Val Acc=0.9920, Val IoU=0.9645
# Epoch 44: Loss=0.3168, Acc=0.9962, IoU=0.9833 | Val Loss=0.3213, Val Acc=0.9916, Val IoU=0.9626
# Epoch 45: Loss=0.3167, Acc=0.9964, IoU=0.9838 | Val Loss=0.3225, Val Acc=0.9903, Val IoU=0.9567
# Epoch 46: Loss=0.3166, Acc=0.9965, IoU=0.9843 | Val Loss=0.3210, Val Acc=0.9919, Val IoU=0.9640
# Epoch 47: Loss=0.3164, Acc=0.9967, IoU=0.9852 | Val Loss=0.3214, Val Acc=0.9915, Val IoU=0.9620
# Epoch 48: Loss=0.3163, Acc=0.9967, IoU=0.9855 | Val Loss=0.3210, Val Acc=0.9918, Val IoU=0.9639
# Epoch 49: Loss=0.3165, Acc=0.9966, IoU=0.9847 | Val Loss=0.3224, Val Acc=0.9904, Val IoU=0.9573
# Epoch 50: Loss=0.3165, Acc=0.9966, IoU=0.9847 | Val Loss=0.3213, Val Acc=0.9915, Val IoU=0.9623

# %%
# ========= 训练曲线可视化 ========= #

epochs = range(1, EPOCHS + 1)
plt.figure(figsize=(18, 5))

# Loss
plt.subplot(1, 3, 1)
plt.plot(epochs, train_loss_list, label='Train Loss')
plt.plot(epochs, val_loss_list, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()

# Accuracy
plt.subplot(1, 3, 2)
plt.plot(epochs, train_acc_list, label='Train Accuracy')
plt.plot(epochs, val_acc_list, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()

# IoU
plt.subplot(1, 3, 3)
plt.plot(epochs, train_iou_list, label='Train IoU')
plt.plot(epochs, val_iou_list, label='Val IoU')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.title('Training & Validation IoU')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save_weights('my_model_weights.weights.h5')
model.save('my_model_full.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /environment/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall
import pickle

# with open("weights_tf10_compatible.pkl", "rb") as f:
#     weights = pickle.load(f)
# models.set_weights(weights)
model.load_weights('my_model_weights.weights.h5')


miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()


cmap = ListedColormap(['black', 'green', 'red'])

#  每轮展示多少图像
num = 10

#  从验证集取一个 batch
for image, mask in dataset_test.take(1):
    # 模型预测（logits -> 类别索引）
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1) for broadcasting

    # 可视化结果
    fig = plt.figure(figsize=(15, num * 5))

    for i in range(num):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

        plt.subplot(num, 4, i * 4 + 1)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(image[i]))
        plt.title("Input Image")

        plt.subplot(num, 4, i * 4 + 2)
        plt.imshow(true_mask, cmap=cmap, interpolation='nearest')
        plt.title("True Mask")

        plt.subplot(num, 4, i * 4 + 3)
        plt.imshow(pred, cmap=cmap, interpolation='nearest')
        plt.title("Predicted Mask")

        plt.subplot(num, 4, i * 4 + 4)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(image[i]), alpha=0.7)
        plt.imshow(pred, cmap=cmap, alpha=0.3, interpolation='nearest')
        plt.title("Overlay")

    plt.tight_layout()
    plt.show()

print(" Evaluation Metrics")
print("Mean IoU   :", miou_metric.result().numpy())
print("Accuracy   :", accuracy_metric.result().numpy())
print("Precision  :", precision_metric.result().numpy())
print("Recall     :", recall_metric.result().numpy())
# Out:
# 1/1 [==============================] - 0s 330ms/step
#  Evaluation Metrics
# Mean IoU   : 0.9643228
# Accuracy   : 0.9917236
# Precision  : 0.9883922
# Recall     : 0.9485598

# %%
import tensorflow as tf
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall

miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()

cmap = ListedColormap(['black', 'green', 'red'])

for image, mask in dataset_test:
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1)

    for i in range(image.shape[0]):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

print("\n Evaluation Metrics on Test Set")
print("Mean IoU   :", round(miou_metric.result().numpy(), 4))
print("Accuracy   :", round(accuracy_metric.result().numpy(), 4))
print("Precision  :", round(precision_metric.result().numpy(), 4))
print("Recall     :", round(recall_metric.result().numpy(), 4))
# Out:
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 5s 5s/step
#
#  Evaluation Metrics on Test Set
# Mean IoU   : 0.9625
# Accuracy   : 0.9915
# Precision  : 0.9738
# Recall     : 0.9588

# %%
import tensorflow as tf
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall
import numpy as np

# with open("weights_tf10_compatible.pkl", "rb") as f:
#     weights = pickle.load(f)
model.load_weights('my_model_weights.weights.h5')

miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()

num_classes = 2
confusion_matrix = np.zeros((num_classes, num_classes), dtype=np.int64)

cmap = ListedColormap(['black', 'green', 'red'])

for image, mask in dataset_test:
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1)

    for i in range(image.shape[0]):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

        y_true = tf.reshape(true_mask, [-1])
        y_pred = tf.reshape(pred, [-1])
        cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=num_classes).numpy()
        confusion_matrix += cm

dice_per_class = []
for i in range(num_classes):
    TP = confusion_matrix[i, i]
    FP = np.sum(confusion_matrix[:, i]) - TP
    FN = np.sum(confusion_matrix[i, :]) - TP
    denom = 2 * TP + FP + FN
    dice = 2 * TP / denom if denom > 0 else 0.0
    dice_per_class.append(dice)

mean_dice = np.mean(dice_per_class)

print("\n Evaluation Metrics on Test Set")
print("Mean IoU   :", round(miou_metric.result().numpy(), 4))
print("Accuracy   :", round(accuracy_metric.result().numpy(), 4))
print("Precision  :", round(precision_metric.result().numpy(), 4))
print("Recall     :", round(recall_metric.result().numpy(), 4))
print("Dice Coef. :", [f"Class {i}: {round(d, 4)}" for i, d in enumerate(dice_per_class)])
print("Mean Dice  :", round(mean_dice, 4))
# Out:
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
#
#  Evaluation Metrics on Test Set
# Mean IoU   : 0.9625
# Accuracy   : 0.9915
# Precision  : 0.9738
# Recall     : 0.9588
# Dice Coef. : ['Class 0: 0.9951', 'Class 1: 0.9663']
# Mean Dice  : 0.9807
