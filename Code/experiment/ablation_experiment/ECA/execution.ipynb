# %%
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
from data_preprocessing import create_segmentation_datasets
# Out:
# 2025-08-10 17:16:02.031132: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-10 17:16:02.061745: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-10 17:16:02.643631: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
image_dir = '/home/featurize/data/segmentation_dataset/images'
mask_dir = '/home/featurize/data/segmentation_dataset/masks'

dataset_train, dataset_val, dataset_test = create_segmentation_datasets(image_dir=image_dir, mask_dir=mask_dir, batch_size=24, val_split=0.2, test_split=0.1)

for imgs, masks in dataset_train.take(1):
    print('Train batch images:', imgs.shape, 'masks:', masks.shape)
for imgs, masks in dataset_val.take(1):
    print('Val batch images:', imgs.shape, 'masks:', masks.shape)
for imgs, masks in dataset_test.take(1):
    print('Test batch images:', imgs.shape, 'masks:', masks.shape)
# Out:
# Training samples: 4634, validation samples: 1324, test samples: 662
# 2025-08-10 17:16:03.327205: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:16:03.330923: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:16:03.331055: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:16:03.332744: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:16:03.332872: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:16:03.332967: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:16:03.698181: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:16:03.698345: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:16:03.698447: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:16:03.698518: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-08-10 17:16:03.698539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22108 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:10:00.0, compute capability: 8.9
# Train batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)
# Val batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)
# Test batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)

# %%
# import tensorflow as tf
# import numpy as np
# from collections import Counter

# def count_classes_in_dataset(dataset):
#     total_counter = Counter()

#     for batch in dataset:
#         images, masks = batch
#         flat_masks = tf.reshape(masks, [-1])
#         result = tf.unique_with_counts(flat_masks)
#         unique_vals = result.y
#         counts = result.count

#         for val, count in zip(unique_vals.numpy(), counts.numpy()):
#             total_counter[int(val)] += int(count)

#     print("\n Dataset 中的类别总分布：")
#     for cls in sorted(total_counter.keys()):
#         print(f"类 {cls}: {total_counter[cls]} 像素")

#     return total_counter

# # 示例调用
# count_classes_in_dataset(dataset_train)

# %%
import matplotlib.pyplot as plt
import numpy as np

for img_batch, mask_batch in dataset_train.take(1):
    img = img_batch[0].numpy()
    mask = mask_batch[0].numpy()

    # 1. 将图像从 [-1, 1] 转回 [0, 1] 浮点图像
    img_display = (img + 1.0) / 2.0
    img_display = np.clip(img_display, 0.0, 1.0)

    # 2. 将 mask squeeze，转换为 uint8，用于灰度显示
    mask_display = np.squeeze(mask).astype(np.uint8)

    # 可视化
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(img_display, cmap='gray', vmin=0.0, vmax=1.0)  # 显式指定范围
    plt.axis('off')
    plt.title("Augmented Image")

    plt.subplot(1, 2, 2)
    plt.imshow(mask_display, cmap='gray', vmin=0, vmax=1)  # 确保 0=黑，1=白
    plt.axis('off')
    plt.title("Mask")

    plt.show()

# %%
from model_test import model

# %%
model = model(img_height=384, img_width=508, classes=2)
model.summary()
# Out:
# *** Output Shape: (None, 384, 508, 2) ***
# Model: "ASPP_Edge_Fusion_noECA"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 384, 508, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 191, 253, 32)         864       ['input_1[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 191, 253, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 191, 253, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 189, 251, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 189, 251, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 189, 251, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 189, 251, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 189, 251, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 189, 251, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 189, 251, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 189, 251, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d (Conv2D)             (None, 95, 126, 128)         8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 95, 126, 128)         0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (Batch  (None, 95, 126, 128)         512       ['conv2d[0][0]']
#  Normalization)
#
#  add (Add)                   (None, 95, 126, 128)         0         ['block2_pool[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activ  (None, 95, 126, 128)         0         ['add[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 95, 126, 256)         33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 95, 126, 256)         1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 95, 126, 256)         0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 95, 126, 256)         67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 95, 126, 256)         1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 63, 256)          32768     ['add[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 48, 63, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (Bat  (None, 48, 63, 256)          1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 48, 63, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 48, 63, 256)          0         ['add_1[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 48, 63, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 48, 63, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 48, 63, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 48, 63, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 48, 63, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 24, 32, 728)          186368    ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 24, 32, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (Bat  (None, 24, 32, 728)          2912      ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 24, 32, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_2[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_3 (Add)                 (None, 24, 32, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_2[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_3[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_4 (Add)                 (None, 24, 32, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_3[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_4[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_5 (Add)                 (None, 24, 32, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_4[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_5[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_6 (Add)                 (None, 24, 32, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_5[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_6[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_7 (Add)                 (None, 24, 32, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_6[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 24, 32, 728)          0         ['add_7[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 24, 32, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 24, 32, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 24, 32, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 24, 32, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 24, 32, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 24, 32, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 24, 32, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 24, 32, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_8 (Add)                 (None, 24, 32, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_7[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 24, 32, 728)          0         ['add_8[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 24, 32, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 24, 32, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 24, 32, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 24, 32, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 24, 32, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 24, 32, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 24, 32, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 24, 32, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 24, 32, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 24, 32, 728)          0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 24, 32, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 24, 32, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 24, 32, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 24, 32, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 24, 32, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 24, 32, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 24, 32, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 24, 32, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 24, 32, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 24, 32, 728)          0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 24, 32, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 24, 32, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 24, 32, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 24, 32, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 24, 32, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 12, 16, 1024)         745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 12, 16, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 12, 16, 1024)         4096      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 12, 16, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 12, 16, 1536)         1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 12, 16, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 12, 16, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 12, 16, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 12, 16, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 12, 16, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  depthwise_conv2d_2 (Depthw  (None, 12, 16, 2048)         18432     ['block14_sepconv2_act[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_3 (Depthw  (None, 12, 16, 2048)         18432     ['block14_sepconv2_act[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_4 (Depthw  (None, 12, 16, 2048)         18432     ['block14_sepconv2_act[0][0]']
#  iseConv2D)
#
#  average_pooling2d (Average  (None, 1, 1, 2048)           0         ['block14_sepconv2_act[0][0]']
#  Pooling2D)
#
#  batch_normalization_7 (Bat  (None, 12, 16, 2048)         8192      ['depthwise_conv2d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 12, 16, 2048)         8192      ['depthwise_conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 12, 16, 2048)         8192      ['depthwise_conv2d_4[0][0]']
#  tchNormalization)
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 128)            262144    ['average_pooling2d[0][0]']
#
#  activation_3 (Activation)   (None, 12, 16, 2048)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 12, 16, 2048)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 12, 16, 2048)         0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  batch_normalization_5 (Bat  (None, 1, 1, 128)            512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 12, 16, 128)          262144    ['block14_sepconv2_act[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 12, 16, 128)          262144    ['activation_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 12, 16, 128)          262144    ['activation_5[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 12, 16, 128)          262144    ['activation_7[0][0]']
#
#  depthwise_conv2d (Depthwis  (None, 48, 63, 256)          2304      ['block3_pool[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_1 (Depthw  (None, 48, 63, 256)          2304      ['block3_pool[0][0]']
#  iseConv2D)
#
#  activation_1 (Activation)   (None, 1, 1, 128)            0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  batch_normalization_6 (Bat  (None, 12, 16, 128)          512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 12, 16, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 12, 16, 128)          512       ['conv2d_8[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 12, 16, 128)          512       ['conv2d_9[0][0]']
#  tchNormalization)
#
#  abs_gx (Lambda)             (None, 48, 63, 256)          0         ['depthwise_conv2d[0][0]']
#
#  abs_gy (Lambda)             (None, 48, 63, 256)          0         ['depthwise_conv2d_1[0][0]']
#
#  activation_1_upsample (Lam  (None, 12, 16, 128)          0         ['activation_1[0][0]']
#  bda)
#
#  activation_2 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_8 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 48, 63, 256)          0         ['abs_gx[0][0]',
#                                                                      'abs_gy[0][0]']
#
#  concatenate (Concatenate)   (None, 12, 16, 640)          0         ['activation_1_upsample[0][0]'
#                                                                     , 'activation_2[0][0]',
#                                                                      'activation_4[0][0]',
#                                                                      'activation_6[0][0]',
#                                                                      'activation_8[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 48, 63, 128)          32768     ['add_12[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 12, 16, 128)          81920     ['concatenate[0][0]']
#
#  batch_normalization_4 (Bat  (None, 48, 63, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_13 (Ba  (None, 12, 16, 128)          512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation (Activation)     (None, 48, 63, 128)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_upsample (Lambd  (None, 12, 16, 128)          0         ['activation[0][0]']
#  a)
#
#  add_13 (Add)                (None, 12, 16, 128)          0         ['activation_9[0][0]',
#                                                                      'activation_upsample[0][0]']
#
#  add_13_upsample (Lambda)    (None, 384, 508, 128)        0         ['add_13[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 384, 508, 2)          258       ['add_13_upsample[0][0]']
#
# ==================================================================================================
# Total params: 22375210 (85.35 MB)
# Trainable params: 22301994 (85.08 MB)
# Non-trainable params: 73216 (286.00 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# ========= 自定义 Edge-Aware 组合损失 ========= #

def gradient_difference_loss(y_true, y_pred):
    dy_true, dx_true = tf.image.image_gradients(tf.cast(y_true, tf.float32))
    dy_pred, dx_pred = tf.image.image_gradients(tf.cast(y_pred, tf.float32))
    grad_diff_y = tf.abs(dy_pred - dy_true)
    grad_diff_x = tf.abs(dx_pred - dx_true)
    return tf.reduce_mean(grad_diff_y + grad_diff_x)


def dice_loss(y_true, y_pred, smooth=1e-6):
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1. - dice


class EdgeAwareLoss:
    def __init__(self, alpha=0.4, beta=0.6, gamma=2.0, num_classes=2):
        self.alpha = alpha  # BCE
        self.beta = beta    # Dice
        self.gamma = gamma  # GDL
        self.num_classes = num_classes
        self.bce_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=False)

    def __call__(self, y_true, y_pred):
        # 修复标签维度问题
        y_true = tf.squeeze(y_true, axis=-1)  # ⬅️ 关键修复点
        y_true_oh = tf.one_hot(tf.cast(y_true, tf.int32), depth=self.num_classes)
        y_pred_clipped = tf.clip_by_value(y_pred, 1e-6, 1.0 - 1e-6)

        # BCE Loss
        bce = self.bce_fn(y_true_oh, y_pred_clipped)

        # Dice Loss（对每个类求平均）
        dice = 0
        for i in range(self.num_classes):
            dice += dice_loss(y_true_oh[..., i], y_pred_clipped[..., i])
        dice /= self.num_classes

        # GDL Loss
        gdl = gradient_difference_loss(y_true_oh, y_pred_clipped)

        return self.alpha * bce + self.beta * dice + self.gamma * gdl

# ========= 指标定义 ========= #

class MeanIoU(tf.keras.metrics.MeanIoU):
    def __call__(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().__call__(y_true, y_pred, sample_weight=sample_weight)

# ========= 初始化优化器 & 损失 ========= #

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
loss_object = EdgeAwareLoss(alpha=0.4, beta=0.6, gamma=2.0, num_classes=2)

# ========= 训练 & 验证指标 ========= #

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')
train_iou = MeanIoU(2, name='train_iou')

test_loss = tf.keras.metrics.Mean(name='test_loss')
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='test_accuracy')
test_iou = MeanIoU(2, name='test_iou')

# ========= 单步训练与测试 ========= #

@tf.function
def train_step(images, labels):
    with tf.GradientTape() as tape:
        predictions = model(images)
        loss = loss_object(labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    train_loss(loss)
    train_accuracy(labels, predictions)
    train_iou(labels, predictions)

@tf.function
def test_step(images, labels):
    predictions = model(images)
    t_loss = loss_object(labels, predictions)

    test_loss(t_loss)
    test_accuracy(labels, predictions)
    test_iou(labels, predictions)

# ========= 训练主循环 ========= #

EPOCHS = 50

train_loss_list = []
train_accuracy_list = []
train_iou_list = []

val_loss_list = []
val_accuracy_list = []
val_iou_list = []

for epoch in range(EPOCHS):
    train_loss.reset_state()
    train_accuracy.reset_state()
    train_iou.reset_state()
    test_loss.reset_state()
    test_accuracy.reset_state()
    test_iou.reset_state()

    for images, labels in dataset_train:
        train_step(images, labels)

    for test_images, test_labels in dataset_val:
        test_step(test_images, test_labels)

    train_loss_list.append(train_loss.result().numpy())
    train_accuracy_list.append(train_accuracy.result().numpy())
    train_iou_list.append(train_iou.result().numpy())

    val_loss_list.append(test_loss.result().numpy())
    val_accuracy_list.append(test_accuracy.result().numpy())
    val_iou_list.append(test_iou.result().numpy())

    print(f"Epoch {epoch+1:02d}: "
          f"Loss={train_loss.result():.4f}, "
          f"Acc={train_accuracy.result():.4f}, "
          f"IoU={train_iou.result():.4f} | "
          f"Val Loss={test_loss.result():.4f}, "
          f"Val Acc={test_accuracy.result():.4f}, "
          f"Val IoU={test_iou.result():.4f}")
# Out:
# 2025-08-10 17:16:14.509883: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-08-10 17:16:16.138704: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.138764: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.138780: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.138793: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.138806: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.138819: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.138830: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.138842: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.138854: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.138867: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.393697: W tensorflow/core/kernels/gpu_utils.cc:50] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2025-08-10 17:16:19.146981: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f567603fc70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-08-10 17:16:19.147019: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-08-10 17:16:19.151031: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-08-10 17:16:19.279552: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-08-10 17:17:46.582176: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch 01: Loss=0.1687, Acc=0.9434, IoU=0.7855 | Val Loss=0.0699, Val Acc=0.9794, Val IoU=0.9140
# Epoch 02: Loss=0.0601, Acc=0.9829, IoU=0.9272 | Val Loss=0.0579, Val Acc=0.9841, Val IoU=0.9306
# Epoch 03: Loss=0.0503, Acc=0.9864, IoU=0.9414 | Val Loss=0.0503, Val Acc=0.9866, Val IoU=0.9423
# Epoch 04: Loss=0.0462, Acc=0.9879, IoU=0.9475 | Val Loss=0.0515, Val Acc=0.9864, Val IoU=0.9426
# Epoch 05: Loss=0.0422, Acc=0.9893, IoU=0.9534 | Val Loss=0.0491, Val Acc=0.9872, Val IoU=0.9458
# Epoch 06: Loss=0.0396, Acc=0.9902, IoU=0.9574 | Val Loss=0.0508, Val Acc=0.9869, Val IoU=0.9447
# Epoch 07: Loss=0.0380, Acc=0.9908, IoU=0.9599 | Val Loss=0.0475, Val Acc=0.9881, Val IoU=0.9477
# Epoch 08: Loss=0.0377, Acc=0.9909, IoU=0.9602 | Val Loss=0.0494, Val Acc=0.9875, Val IoU=0.9473
# Epoch 09: Loss=0.0362, Acc=0.9914, IoU=0.9624 | Val Loss=0.0428, Val Acc=0.9898, Val IoU=0.9554
# Epoch 10: Loss=0.0362, Acc=0.9915, IoU=0.9626 | Val Loss=0.0471, Val Acc=0.9882, Val IoU=0.9500
# Epoch 11: Loss=0.0340, Acc=0.9923, IoU=0.9660 | Val Loss=0.0396, Val Acc=0.9910, Val IoU=0.9606
# Epoch 12: Loss=0.0320, Acc=0.9930, IoU=0.9691 | Val Loss=0.0416, Val Acc=0.9905, Val IoU=0.9591
# Epoch 13: Loss=0.0313, Acc=0.9932, IoU=0.9701 | Val Loss=0.0403, Val Acc=0.9909, Val IoU=0.9604
# Epoch 14: Loss=0.0332, Acc=0.9925, IoU=0.9671 | Val Loss=0.0429, Val Acc=0.9896, Val IoU=0.9556
# Epoch 15: Loss=0.0322, Acc=0.9929, IoU=0.9686 | Val Loss=0.0465, Val Acc=0.9889, Val IoU=0.9530
# Epoch 16: Loss=0.0315, Acc=0.9932, IoU=0.9699 | Val Loss=0.0469, Val Acc=0.9891, Val IoU=0.9537
# Epoch 17: Loss=0.0353, Acc=0.9920, IoU=0.9647 | Val Loss=0.0396, Val Acc=0.9911, Val IoU=0.9616
# Epoch 18: Loss=0.0301, Acc=0.9936, IoU=0.9719 | Val Loss=0.0458, Val Acc=0.9895, Val IoU=0.9555
# Epoch 19: Loss=0.0298, Acc=0.9937, IoU=0.9721 | Val Loss=0.0434, Val Acc=0.9899, Val IoU=0.9571
# Epoch 20: Loss=0.0300, Acc=0.9936, IoU=0.9719 | Val Loss=0.0427, Val Acc=0.9902, Val IoU=0.9566
# Epoch 21: Loss=0.0293, Acc=0.9938, IoU=0.9728 | Val Loss=0.0490, Val Acc=0.9889, Val IoU=0.9506
# Epoch 22: Loss=0.0286, Acc=0.9941, IoU=0.9739 | Val Loss=0.0391, Val Acc=0.9916, Val IoU=0.9631
# Epoch 23: Loss=0.0259, Acc=0.9950, IoU=0.9779 | Val Loss=0.0368, Val Acc=0.9923, Val IoU=0.9663
# Epoch 24: Loss=0.0263, Acc=0.9949, IoU=0.9774 | Val Loss=0.0389, Val Acc=0.9915, Val IoU=0.9623
# Epoch 25: Loss=0.0283, Acc=0.9942, IoU=0.9744 | Val Loss=0.0423, Val Acc=0.9905, Val IoU=0.9577
# Epoch 26: Loss=0.0307, Acc=0.9934, IoU=0.9707 | Val Loss=0.0373, Val Acc=0.9919, Val IoU=0.9648
# Epoch 27: Loss=0.0288, Acc=0.9940, IoU=0.9735 | Val Loss=0.0365, Val Acc=0.9922, Val IoU=0.9660
# Epoch 28: Loss=0.0257, Acc=0.9951, IoU=0.9781 | Val Loss=0.0358, Val Acc=0.9926, Val IoU=0.9678
# Epoch 29: Loss=0.0247, Acc=0.9954, IoU=0.9798 | Val Loss=0.0362, Val Acc=0.9927, Val IoU=0.9679
# Epoch 30: Loss=0.0237, Acc=0.9957, IoU=0.9810 | Val Loss=0.0349, Val Acc=0.9930, Val IoU=0.9693
# Epoch 31: Loss=0.0236, Acc=0.9958, IoU=0.9813 | Val Loss=0.0364, Val Acc=0.9927, Val IoU=0.9680
# Epoch 32: Loss=0.0238, Acc=0.9957, IoU=0.9809 | Val Loss=0.0405, Val Acc=0.9915, Val IoU=0.9635
# Epoch 33: Loss=0.0259, Acc=0.9950, IoU=0.9779 | Val Loss=0.0370, Val Acc=0.9921, Val IoU=0.9659
# Epoch 34: Loss=0.0265, Acc=0.9948, IoU=0.9771 | Val Loss=0.0369, Val Acc=0.9919, Val IoU=0.9647
# Epoch 35: Loss=0.0276, Acc=0.9945, IoU=0.9755 | Val Loss=0.0384, Val Acc=0.9917, Val IoU=0.9633
# Epoch 36: Loss=0.0255, Acc=0.9951, IoU=0.9784 | Val Loss=0.0383, Val Acc=0.9923, Val IoU=0.9658
# Epoch 38: Loss=0.0240, Acc=0.9957, IoU=0.9807 | Val Loss=0.0348, Val Acc=0.9932, Val IoU=0.9698
# Epoch 39: Loss=0.0251, Acc=0.9953, IoU=0.9789 | Val Loss=0.0355, Val Acc=0.9928, Val IoU=0.9684
# Epoch 40: Loss=0.0259, Acc=0.9950, IoU=0.9779 | Val Loss=0.0361, Val Acc=0.9923, Val IoU=0.9667
# Epoch 41: Loss=0.0256, Acc=0.9951, IoU=0.9782 | Val Loss=0.0396, Val Acc=0.9915, Val IoU=0.9633
# Epoch 42: Loss=0.0254, Acc=0.9952, IoU=0.9785 | Val Loss=0.0434, Val Acc=0.9903, Val IoU=0.9586
# Epoch 43: Loss=0.0276, Acc=0.9945, IoU=0.9755 | Val Loss=0.0387, Val Acc=0.9917, Val IoU=0.9642
# Epoch 44: Loss=0.0247, Acc=0.9954, IoU=0.9796 | Val Loss=0.0363, Val Acc=0.9925, Val IoU=0.9675
# Epoch 45: Loss=0.0251, Acc=0.9953, IoU=0.9789 | Val Loss=0.0352, Val Acc=0.9929, Val IoU=0.9685
# Epoch 46: Loss=0.0257, Acc=0.9950, IoU=0.9780 | Val Loss=0.0385, Val Acc=0.9919, Val IoU=0.9638
# Epoch 47: Loss=0.0246, Acc=0.9954, IoU=0.9797 | Val Loss=0.0383, Val Acc=0.9921, Val IoU=0.9650
# Epoch 48: Loss=0.0238, Acc=0.9957, IoU=0.9809 | Val Loss=0.0369, Val Acc=0.9927, Val IoU=0.9678
# Epoch 49: Loss=0.0231, Acc=0.9959, IoU=0.9819 | Val Loss=0.0355, Val Acc=0.9931, Val IoU=0.9694
# Epoch 50: Loss=0.0227, Acc=0.9960, IoU=0.9823 | Val Loss=0.0350, Val Acc=0.9933, Val IoU=0.9705

# %%
# ========= 训练曲线可视化 ========= #

epochs = range(1, EPOCHS + 1)
plt.figure(figsize=(18, 5))

# Loss
plt.subplot(1, 3, 1)
plt.plot(epochs, train_loss_list, label='Train Loss')
plt.plot(epochs, val_loss_list, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()

# Accuracy
plt.subplot(1, 3, 2)
plt.plot(epochs, train_accuracy_list, label='Train Accuracy')
plt.plot(epochs, val_accuracy_list, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()

# IoU
plt.subplot(1, 3, 3)
plt.plot(epochs, train_iou_list, label='Train IoU')
plt.plot(epochs, val_iou_list, label='Val IoU')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.title('Training & Validation IoU')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save_weights('my_model_weights.weights.h5')
model.save('my_model_full.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /environment/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall
import pickle

# with open("weights_tf10_compatible.pkl", "rb") as f:
#     weights = pickle.load(f)
# models.set_weights(weights)
model.load_weights('my_model_weights.weights.h5')


miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()


cmap = ListedColormap(['black', 'green', 'red'])

#  每轮展示多少图像
num = 10

#  从验证集取一个 batch
for image, mask in dataset_test.take(1):
    # 模型预测（logits -> 类别索引）
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1) for broadcasting

    # 可视化结果
    fig = plt.figure(figsize=(15, num * 5))

    for i in range(num):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

        plt.subplot(num, 4, i * 4 + 1)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(image[i]))
        plt.title("Input Image")

        plt.subplot(num, 4, i * 4 + 2)
        plt.imshow(true_mask, cmap=cmap, interpolation='nearest')
        plt.title("True Mask")

        plt.subplot(num, 4, i * 4 + 3)
        plt.imshow(pred, cmap=cmap, interpolation='nearest')
        plt.title("Predicted Mask")

        plt.subplot(num, 4, i * 4 + 4)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(image[i]), alpha=0.7)
        plt.imshow(pred, cmap=cmap, alpha=0.3, interpolation='nearest')
        plt.title("Overlay")

    plt.tight_layout()
    plt.show()

print(" Evaluation Metrics")
print("Mean IoU   :", miou_metric.result().numpy())
print("Accuracy   :", accuracy_metric.result().numpy())
print("Precision  :", precision_metric.result().numpy())
print("Recall     :", recall_metric.result().numpy())
# Out:
# 1/1 [==============================] - 1s 541ms/step
#  Evaluation Metrics
# Mean IoU   : 0.9754149
# Accuracy   : 0.9958339
# Precision  : 0.984657
# Recall     : 0.9698425

# %%
import tensorflow as tf
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall

miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()

cmap = ListedColormap(['black', 'green', 'red'])

for image, mask in dataset_test:
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1)

    for i in range(image.shape[0]):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

print("\n Evaluation Metrics on Test Set")
print("Mean IoU   :", round(miou_metric.result().numpy(), 4))
print("Accuracy   :", round(accuracy_metric.result().numpy(), 4))
print("Precision  :", round(precision_metric.result().numpy(), 4))
print("Recall     :", round(recall_metric.result().numpy(), 4))
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 204ms/step
#
#  Evaluation Metrics on Test Set
# Mean IoU   : 0.9705
# Accuracy   : 0.9934
# Precision  : 0.9777
# Recall     : 0.9695

# %%
import tensorflow as tf
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall
import numpy as np

# with open("weights_tf10_compatible.pkl", "rb") as f:
#     weights = pickle.load(f)
model.load_weights('my_model_weights.weights.h5')

miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()

num_classes = 2
confusion_matrix = np.zeros((num_classes, num_classes), dtype=np.int64)

cmap = ListedColormap(['black', 'green', 'red'])

for image, mask in dataset_test:
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1)

    for i in range(image.shape[0]):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

        y_true = tf.reshape(true_mask, [-1])
        y_pred = tf.reshape(pred, [-1])
        cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=num_classes).numpy()
        confusion_matrix += cm

dice_per_class = []
for i in range(num_classes):
    TP = confusion_matrix[i, i]
    FP = np.sum(confusion_matrix[:, i]) - TP
    FN = np.sum(confusion_matrix[i, :]) - TP
    denom = 2 * TP + FP + FN
    dice = 2 * TP / denom if denom > 0 else 0.0
    dice_per_class.append(dice)

mean_dice = np.mean(dice_per_class)

print("\n Evaluation Metrics on Test Set")
print("Mean IoU   :", round(miou_metric.result().numpy(), 4))
print("Accuracy   :", round(accuracy_metric.result().numpy(), 4))
print("Precision  :", round(precision_metric.result().numpy(), 4))
print("Recall     :", round(recall_metric.result().numpy(), 4))
print("Dice Coef. :", [f"Class {i}: {round(d, 4)}" for i, d in enumerate(dice_per_class)])
print("Mean Dice  :", round(mean_dice, 4))
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
#
#  Evaluation Metrics on Test Set
# Mean IoU   : 0.9705
# Accuracy   : 0.9934
# Precision  : 0.9777
# Recall     : 0.9695
# Dice Coef. : ['Class 0: 0.9962', 'Class 1: 0.9736']
# Mean Dice  : 0.9849
