# %%
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
from data_preprocessing import create_segmentation_datasets
# Out:
# 2025-08-10 17:15:57.840569: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-10 17:15:58.633300: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
image_dir = '/home/featurize/data/segmentation_dataset/images'
mask_dir = '/home/featurize/data/segmentation_dataset/masks'

dataset_train, dataset_val, dataset_test = create_segmentation_datasets(image_dir=image_dir, mask_dir=mask_dir, batch_size=24, val_split=0.2, test_split=0.1)

for imgs, masks in dataset_train.take(1):
    print('Train batch images:', imgs.shape, 'masks:', masks.shape)
for imgs, masks in dataset_val.take(1):
    print('Val batch images:', imgs.shape, 'masks:', masks.shape)
for imgs, masks in dataset_test.take(1):
    print('Test batch images:', imgs.shape, 'masks:', masks.shape)
# Out:
# Training samples: 4634, validation samples: 1324, test samples: 662
# 2025-08-10 17:15:59.510666: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:15:59.514947: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:15:59.515139: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:15:59.516224: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:15:59.516385: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:15:59.516517: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:15:59.946253: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:15:59.946430: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:15:59.946559: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-10 17:15:59.946671: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-08-10 17:15:59.946700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22108 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:10:00.0, compute capability: 8.9
# Train batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)
# Val batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)
# Test batch images: (24, 384, 508, 3) masks: (24, 384, 508, 1)

# %%
# import tensorflow as tf
# import numpy as np
# from collections import Counter

# def count_classes_in_dataset(dataset):
#     total_counter = Counter()

#     for batch in dataset:
#         images, masks = batch
#         flat_masks = tf.reshape(masks, [-1])
#         result = tf.unique_with_counts(flat_masks)
#         unique_vals = result.y
#         counts = result.count

#         for val, count in zip(unique_vals.numpy(), counts.numpy()):
#             total_counter[int(val)] += int(count)

#     print("\n Dataset 中的类别总分布：")
#     for cls in sorted(total_counter.keys()):
#         print(f"类 {cls}: {total_counter[cls]} 像素")

#     return total_counter

# # 示例调用
# count_classes_in_dataset(dataset_train)

# %%
import matplotlib.pyplot as plt
import numpy as np

for img_batch, mask_batch in dataset_train.take(1):
    img = img_batch[0].numpy()
    mask = mask_batch[0].numpy()

    # 1. 将图像从 [-1, 1] 转回 [0, 1] 浮点图像
    img_display = (img + 1.0) / 2.0
    img_display = np.clip(img_display, 0.0, 1.0)

    # 2. 将 mask squeeze，转换为 uint8，用于灰度显示
    mask_display = np.squeeze(mask).astype(np.uint8)

    # 可视化
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(img_display, cmap='gray', vmin=0.0, vmax=1.0)  # 显式指定范围
    plt.axis('off')
    plt.title("Augmented Image")

    plt.subplot(1, 2, 2)
    plt.imshow(mask_display, cmap='gray', vmin=0, vmax=1)  # 确保 0=黑，1=白
    plt.axis('off')
    plt.title("Mask")

    plt.show()

# %%
from model_test import model

# %%
model = model(img_height=384, img_width=508, classes=2)
model.summary()
# Out:
# *** Output Shape: (None, 384, 508, 2) ***
# Model: "ASPP_Only_w_o_Edge"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 384, 508, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 191, 253, 32)         864       ['input_1[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 191, 253, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 191, 253, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 189, 251, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 189, 251, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 189, 251, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 189, 251, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 189, 251, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 189, 251, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 189, 251, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 189, 251, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d (Conv2D)             (None, 95, 126, 128)         8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 95, 126, 128)         0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (Batch  (None, 95, 126, 128)         512       ['conv2d[0][0]']
#  Normalization)
#
#  add (Add)                   (None, 95, 126, 128)         0         ['block2_pool[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activ  (None, 95, 126, 128)         0         ['add[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 95, 126, 256)         33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 95, 126, 256)         1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 95, 126, 256)         0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 95, 126, 256)         67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 95, 126, 256)         1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 63, 256)          32768     ['add[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 48, 63, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (Bat  (None, 48, 63, 256)          1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 48, 63, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 48, 63, 256)          0         ['add_1[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 48, 63, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 48, 63, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 48, 63, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 48, 63, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 48, 63, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 24, 32, 728)          186368    ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 24, 32, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (Bat  (None, 24, 32, 728)          2912      ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 24, 32, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_2[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_3 (Add)                 (None, 24, 32, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_2[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_3[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_4 (Add)                 (None, 24, 32, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_3[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_4[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_5 (Add)                 (None, 24, 32, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_4[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_5[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_6 (Add)                 (None, 24, 32, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_5[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 24, 32, 728)          0         ['add_6[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 24, 32, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 24, 32, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 24, 32, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 24, 32, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 24, 32, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 24, 32, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 24, 32, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 24, 32, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_7 (Add)                 (None, 24, 32, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_6[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 24, 32, 728)          0         ['add_7[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 24, 32, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 24, 32, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 24, 32, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 24, 32, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 24, 32, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 24, 32, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 24, 32, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 24, 32, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_8 (Add)                 (None, 24, 32, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_7[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 24, 32, 728)          0         ['add_8[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 24, 32, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 24, 32, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 24, 32, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 24, 32, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 24, 32, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 24, 32, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 24, 32, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 24, 32, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 24, 32, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 24, 32, 728)          0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 24, 32, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 24, 32, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 24, 32, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 24, 32, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 24, 32, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 24, 32, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 24, 32, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 24, 32, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 24, 32, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 24, 32, 728)          0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 24, 32, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 24, 32, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 24, 32, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 24, 32, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 24, 32, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 12, 16, 1024)         745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 12, 16, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 12, 16, 1024)         4096      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 12, 16, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 12, 16, 1536)         1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 12, 16, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 12, 16, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 12, 16, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 12, 16, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 12, 16, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  global_average_pooling2d (  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#  GlobalAveragePooling2D)
#
#  reshape (Reshape)           (None, 2048, 1)              0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  conv1d (Conv1D)             (None, 2048, 1)              7         ['reshape[0][0]']
#
#  activation (Activation)     (None, 2048, 1)              0         ['conv1d[0][0]']
#
#  reshape_1 (Reshape)         (None, 1, 1, 2048)           0         ['activation[0][0]']
#
#  multiply (Multiply)         (None, 12, 16, 2048)         0         ['block14_sepconv2_act[0][0]',
#                                                                      'reshape_1[0][0]']
#
#  depthwise_conv2d (Depthwis  (None, 12, 16, 2048)         18432     ['multiply[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_1 (Depthw  (None, 12, 16, 2048)         18432     ['multiply[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_2 (Depthw  (None, 12, 16, 2048)         18432     ['multiply[0][0]']
#  iseConv2D)
#
#  average_pooling2d (Average  (None, 1, 1, 2048)           0         ['multiply[0][0]']
#  Pooling2D)
#
#  batch_normalization_6 (Bat  (None, 12, 16, 2048)         8192      ['depthwise_conv2d[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 12, 16, 2048)         8192      ['depthwise_conv2d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 12, 16, 2048)         8192      ['depthwise_conv2d_2[0][0]']
#  tchNormalization)
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 128)            262144    ['average_pooling2d[0][0]']
#
#  activation_3 (Activation)   (None, 12, 16, 2048)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 12, 16, 2048)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 12, 16, 2048)         0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  batch_normalization_4 (Bat  (None, 1, 1, 128)            512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 12, 16, 128)          262144    ['multiply[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 12, 16, 128)          262144    ['activation_3[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 12, 16, 128)          262144    ['activation_5[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 12, 16, 128)          262144    ['activation_7[0][0]']
#
#  activation_1 (Activation)   (None, 1, 1, 128)            0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  batch_normalization_5 (Bat  (None, 12, 16, 128)          512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 12, 16, 128)          512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 12, 16, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 12, 16, 128)          512       ['conv2d_8[0][0]']
#  tchNormalization)
#
#  activation_1_upsample (Lam  (None, 12, 16, 128)          0         ['activation_1[0][0]']
#  bda)
#
#  activation_2 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  concatenate (Concatenate)   (None, 12, 16, 640)          0         ['activation_1_upsample[0][0]'
#                                                                     , 'activation_2[0][0]',
#                                                                      'activation_4[0][0]',
#                                                                      'activation_6[0][0]',
#                                                                      'activation_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 12, 16, 128)          81920     ['concatenate[0][0]']
#
#  batch_normalization_12 (Ba  (None, 12, 16, 128)          512       ['conv2d_9[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 12, 16, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_9_upsample (Lam  (None, 384, 508, 128)        0         ['activation_9[0][0]']
#  bda)
#
#  conv2d_10 (Conv2D)          (None, 384, 508, 2)          258       ['activation_9_upsample[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 22337329 (85.21 MB)
# Trainable params: 22268977 (84.95 MB)
# Non-trainable params: 68352 (267.00 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# ========= 自定义 Edge-Aware 组合损失 ========= #

def gradient_difference_loss(y_true, y_pred):
    dy_true, dx_true = tf.image.image_gradients(tf.cast(y_true, tf.float32))
    dy_pred, dx_pred = tf.image.image_gradients(tf.cast(y_pred, tf.float32))
    grad_diff_y = tf.abs(dy_pred - dy_true)
    grad_diff_x = tf.abs(dx_pred - dx_true)
    return tf.reduce_mean(grad_diff_y + grad_diff_x)


def dice_loss(y_true, y_pred, smooth=1e-6):
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1. - dice


class EdgeAwareLoss:
    def __init__(self, alpha=0.4, beta=0.6, gamma=2.0, num_classes=2):
        self.alpha = alpha  # BCE
        self.beta = beta    # Dice
        self.gamma = gamma  # GDL
        self.num_classes = num_classes
        self.bce_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=False)

    def __call__(self, y_true, y_pred):
        # 修复标签维度问题
        y_true = tf.squeeze(y_true, axis=-1)  # ⬅️ 关键修复点
        y_true_oh = tf.one_hot(tf.cast(y_true, tf.int32), depth=self.num_classes)
        y_pred_clipped = tf.clip_by_value(y_pred, 1e-6, 1.0 - 1e-6)

        # BCE Loss
        bce = self.bce_fn(y_true_oh, y_pred_clipped)

        # Dice Loss（对每个类求平均）
        dice = 0
        for i in range(self.num_classes):
            dice += dice_loss(y_true_oh[..., i], y_pred_clipped[..., i])
        dice /= self.num_classes

        # GDL Loss
        gdl = gradient_difference_loss(y_true_oh, y_pred_clipped)

        return self.alpha * bce + self.beta * dice + self.gamma * gdl

# ========= 指标定义 ========= #

class MeanIoU(tf.keras.metrics.MeanIoU):
    def __call__(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().__call__(y_true, y_pred, sample_weight=sample_weight)

# ========= 初始化优化器 & 损失 ========= #

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
loss_object = EdgeAwareLoss(alpha=0.4, beta=0.6, gamma=2.0, num_classes=2)

# ========= 训练 & 验证指标 ========= #

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')
train_iou = MeanIoU(2, name='train_iou')

test_loss = tf.keras.metrics.Mean(name='test_loss')
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='test_accuracy')
test_iou = MeanIoU(2, name='test_iou')

# ========= 单步训练与测试 ========= #

@tf.function
def train_step(images, labels):
    with tf.GradientTape() as tape:
        predictions = model(images)
        loss = loss_object(labels, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    train_loss(loss)
    train_accuracy(labels, predictions)
    train_iou(labels, predictions)

@tf.function
def test_step(images, labels):
    predictions = model(images)
    t_loss = loss_object(labels, predictions)

    test_loss(t_loss)
    test_accuracy(labels, predictions)
    test_iou(labels, predictions)

# ========= 训练主循环 ========= #

EPOCHS = 50

train_loss_list = []
train_accuracy_list = []
train_iou_list = []

val_loss_list = []
val_accuracy_list = []
val_iou_list = []

for epoch in range(EPOCHS):
    train_loss.reset_state()
    train_accuracy.reset_state()
    train_iou.reset_state()
    test_loss.reset_state()
    test_accuracy.reset_state()
    test_iou.reset_state()

    for images, labels in dataset_train:
        train_step(images, labels)

    for test_images, test_labels in dataset_val:
        test_step(test_images, test_labels)

    train_loss_list.append(train_loss.result().numpy())
    train_accuracy_list.append(train_accuracy.result().numpy())
    train_iou_list.append(train_iou.result().numpy())

    val_loss_list.append(test_loss.result().numpy())
    val_accuracy_list.append(test_accuracy.result().numpy())
    val_iou_list.append(test_iou.result().numpy())

    print(f"Epoch {epoch+1:02d}: "
          f"Loss={train_loss.result():.4f}, "
          f"Acc={train_accuracy.result():.4f}, "
          f"IoU={train_iou.result():.4f} | "
          f"Val Loss={test_loss.result():.4f}, "
          f"Val Acc={test_accuracy.result():.4f}, "
          f"Val IoU={test_iou.result():.4f}")
# Out:
# 2025-08-10 17:16:15.008247: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-08-10 17:16:16.773256: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.773331: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.773352: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.773369: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.773385: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.773401: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.773416: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.773430: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.773445: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:16.773727: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-10 17:16:17.066985: W tensorflow/core/kernels/gpu_utils.cc:50] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2025-08-10 17:16:19.839282: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f77659644a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-08-10 17:16:19.839318: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-08-10 17:16:19.843440: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-08-10 17:16:19.971415: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-08-10 17:17:51.334256: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch 01: Loss=0.1018, Acc=0.9689, IoU=0.8699 | Val Loss=0.0547, Val Acc=0.9848, Val IoU=0.9342
# Epoch 02: Loss=0.0507, Acc=0.9861, IoU=0.9403 | Val Loss=0.0503, Val Acc=0.9864, Val IoU=0.9398
# Epoch 03: Loss=0.0456, Acc=0.9880, IoU=0.9479 | Val Loss=0.0453, Val Acc=0.9882, Val IoU=0.9479
# Epoch 04: Loss=0.0416, Acc=0.9895, IoU=0.9541 | Val Loss=0.0426, Val Acc=0.9892, Val IoU=0.9529
# Epoch 05: Loss=0.0385, Acc=0.9906, IoU=0.9589 | Val Loss=0.0425, Val Acc=0.9893, Val IoU=0.9527
# Epoch 06: Loss=0.0381, Acc=0.9908, IoU=0.9596 | Val Loss=0.0452, Val Acc=0.9881, Val IoU=0.9494
# Epoch 07: Loss=0.0365, Acc=0.9913, IoU=0.9620 | Val Loss=0.0516, Val Acc=0.9862, Val IoU=0.9422
# Epoch 08: Loss=0.0346, Acc=0.9920, IoU=0.9648 | Val Loss=0.0447, Val Acc=0.9888, Val IoU=0.9519
# Epoch 09: Loss=0.0335, Acc=0.9924, IoU=0.9666 | Val Loss=0.0384, Val Acc=0.9907, Val IoU=0.9592
# Epoch 10: Loss=0.0333, Acc=0.9924, IoU=0.9667 | Val Loss=0.0477, Val Acc=0.9875, Val IoU=0.9438
# Epoch 11: Loss=0.0319, Acc=0.9930, IoU=0.9690 | Val Loss=0.0409, Val Acc=0.9900, Val IoU=0.9554
# Epoch 12: Loss=0.0315, Acc=0.9931, IoU=0.9696 | Val Loss=0.0381, Val Acc=0.9910, Val IoU=0.9599
# Epoch 13: Loss=0.0315, Acc=0.9931, IoU=0.9696 | Val Loss=0.0409, Val Acc=0.9901, Val IoU=0.9575
# Epoch 14: Loss=0.0310, Acc=0.9932, IoU=0.9702 | Val Loss=0.0446, Val Acc=0.9887, Val IoU=0.9521
# Epoch 15: Loss=0.0301, Acc=0.9936, IoU=0.9717 | Val Loss=0.0417, Val Acc=0.9900, Val IoU=0.9570
# Epoch 16: Loss=0.0294, Acc=0.9938, IoU=0.9727 | Val Loss=0.0348, Val Acc=0.9922, Val IoU=0.9655
# Epoch 17: Loss=0.0282, Acc=0.9942, IoU=0.9745 | Val Loss=0.0350, Val Acc=0.9924, Val IoU=0.9662
# Epoch 18: Loss=0.0269, Acc=0.9947, IoU=0.9764 | Val Loss=0.0372, Val Acc=0.9919, Val IoU=0.9638
# Epoch 19: Loss=0.0280, Acc=0.9943, IoU=0.9748 | Val Loss=0.0387, Val Acc=0.9910, Val IoU=0.9598
# Epoch 20: Loss=0.0297, Acc=0.9937, IoU=0.9721 | Val Loss=0.0400, Val Acc=0.9907, Val IoU=0.9590
# Epoch 21: Loss=0.0282, Acc=0.9942, IoU=0.9745 | Val Loss=0.0374, Val Acc=0.9917, Val IoU=0.9637
# Epoch 22: Loss=0.0273, Acc=0.9945, IoU=0.9758 | Val Loss=0.0381, Val Acc=0.9916, Val IoU=0.9634
# Epoch 23: Loss=0.0263, Acc=0.9949, IoU=0.9774 | Val Loss=0.0353, Val Acc=0.9924, Val IoU=0.9667
# Epoch 24: Loss=0.0271, Acc=0.9946, IoU=0.9760 | Val Loss=0.0351, Val Acc=0.9922, Val IoU=0.9654
# Epoch 25: Loss=0.0269, Acc=0.9947, IoU=0.9764 | Val Loss=0.0352, Val Acc=0.9921, Val IoU=0.9650
# Epoch 26: Loss=0.0269, Acc=0.9947, IoU=0.9763 | Val Loss=0.0357, Val Acc=0.9921, Val IoU=0.9653
# Epoch 27: Loss=0.0274, Acc=0.9945, IoU=0.9758 | Val Loss=0.0356, Val Acc=0.9921, Val IoU=0.9653
# Epoch 28: Loss=0.0264, Acc=0.9948, IoU=0.9771 | Val Loss=0.0432, Val Acc=0.9898, Val IoU=0.9564
# Epoch 29: Loss=0.0272, Acc=0.9946, IoU=0.9760 | Val Loss=0.0364, Val Acc=0.9918, Val IoU=0.9643
# Epoch 30: Loss=0.0260, Acc=0.9950, IoU=0.9777 | Val Loss=0.0339, Val Acc=0.9928, Val IoU=0.9685
# Epoch 31: Loss=0.0238, Acc=0.9957, IoU=0.9809 | Val Loss=0.0349, Val Acc=0.9929, Val IoU=0.9689
# Epoch 32: Loss=0.0224, Acc=0.9961, IoU=0.9828 | Val Loss=0.0340, Val Acc=0.9933, Val IoU=0.9702
# Epoch 33: Loss=0.0221, Acc=0.9962, IoU=0.9832 | Val Loss=0.0339, Val Acc=0.9932, Val IoU=0.9702
# Epoch 34: Loss=0.0220, Acc=0.9963, IoU=0.9834 | Val Loss=0.0360, Val Acc=0.9927, Val IoU=0.9679
# Epoch 35: Loss=0.0224, Acc=0.9961, IoU=0.9828 | Val Loss=0.0351, Val Acc=0.9929, Val IoU=0.9687
# Epoch 38: Loss=0.0251, Acc=0.9953, IoU=0.9790 | Val Loss=0.0357, Val Acc=0.9920, Val IoU=0.9643
# Epoch 39: Loss=0.0259, Acc=0.9950, IoU=0.9777 | Val Loss=0.0336, Val Acc=0.9928, Val IoU=0.9676
# Epoch 40: Loss=0.0239, Acc=0.9956, IoU=0.9806 | Val Loss=0.0344, Val Acc=0.9929, Val IoU=0.9682
# Epoch 41: Loss=0.0221, Acc=0.9962, IoU=0.9832 | Val Loss=0.0344, Val Acc=0.9931, Val IoU=0.9690
# Epoch 42: Loss=0.0224, Acc=0.9961, IoU=0.9827 | Val Loss=0.0346, Val Acc=0.9929, Val IoU=0.9684
# Epoch 43: Loss=0.0224, Acc=0.9961, IoU=0.9827 | Val Loss=0.0331, Val Acc=0.9934, Val IoU=0.9708
# Epoch 44: Loss=0.0231, Acc=0.9959, IoU=0.9819 | Val Loss=0.0348, Val Acc=0.9930, Val IoU=0.9693
# Epoch 45: Loss=0.0252, Acc=0.9952, IoU=0.9787 | Val Loss=0.0357, Val Acc=0.9925, Val IoU=0.9672
# Epoch 46: Loss=0.0240, Acc=0.9956, IoU=0.9805 | Val Loss=0.0339, Val Acc=0.9931, Val IoU=0.9698
# Epoch 47: Loss=0.0223, Acc=0.9962, IoU=0.9829 | Val Loss=0.0335, Val Acc=0.9934, Val IoU=0.9709
# Epoch 48: Loss=0.0220, Acc=0.9963, IoU=0.9833 | Val Loss=0.0358, Val Acc=0.9928, Val IoU=0.9680
# Epoch 49: Loss=0.0219, Acc=0.9963, IoU=0.9835 | Val Loss=0.0351, Val Acc=0.9930, Val IoU=0.9687
# Epoch 50: Loss=0.0219, Acc=0.9963, IoU=0.9835 | Val Loss=0.0344, Val Acc=0.9932, Val IoU=0.9696

# %%
# ========= 训练曲线可视化 ========= #

epochs = range(1, EPOCHS + 1)
plt.figure(figsize=(18, 5))

# Loss
plt.subplot(1, 3, 1)
plt.plot(epochs, train_loss_list, label='Train Loss')
plt.plot(epochs, val_loss_list, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()

# Accuracy
plt.subplot(1, 3, 2)
plt.plot(epochs, train_accuracy_list, label='Train Accuracy')
plt.plot(epochs, val_accuracy_list, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()

# IoU
plt.subplot(1, 3, 3)
plt.plot(epochs, train_iou_list, label='Train IoU')
plt.plot(epochs, val_iou_list, label='Val IoU')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.title('Training & Validation IoU')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save_weights('my_model_weights.weights.h5')
model.save('my_model_full.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /environment/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall
import pickle

# with open("weights_tf10_compatible.pkl", "rb") as f:
#     weights = pickle.load(f)
# models.set_weights(weights)
model.load_weights('my_model_weights.weights.h5')


miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()


cmap = ListedColormap(['black', 'green', 'red'])

#  每轮展示多少图像
num = 10

#  从验证集取一个 batch
for image, mask in dataset_test.take(1):
    # 模型预测（logits -> 类别索引）
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1) for broadcasting

    # 可视化结果
    fig = plt.figure(figsize=(15, num * 5))

    for i in range(num):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

        plt.subplot(num, 4, i * 4 + 1)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(image[i]))
        plt.title("Input Image")

        plt.subplot(num, 4, i * 4 + 2)
        plt.imshow(true_mask, cmap=cmap, interpolation='nearest')
        plt.title("True Mask")

        plt.subplot(num, 4, i * 4 + 3)
        plt.imshow(pred, cmap=cmap, interpolation='nearest')
        plt.title("Predicted Mask")

        plt.subplot(num, 4, i * 4 + 4)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(image[i]), alpha=0.7)
        plt.imshow(pred, cmap=cmap, alpha=0.3, interpolation='nearest')
        plt.title("Overlay")

    plt.tight_layout()
    plt.show()

print(" Evaluation Metrics")
print("Mean IoU   :", miou_metric.result().numpy())
print("Accuracy   :", accuracy_metric.result().numpy())
print("Precision  :", precision_metric.result().numpy())
print("Recall     :", recall_metric.result().numpy())
# Out:
# 1/1 [==============================] - 1s 786ms/step
#  Evaluation Metrics
# Mean IoU   : 0.963267
# Accuracy   : 0.99221367
# Precision  : 0.975129
# Recall     : 0.9581655

# %%
import tensorflow as tf
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall

miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()

cmap = ListedColormap(['black', 'green', 'red'])

for image, mask in dataset_test:
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1)

    for i in range(image.shape[0]):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

print("\n Evaluation Metrics on Test Set")
print("Mean IoU   :", round(miou_metric.result().numpy(), 4))
print("Accuracy   :", round(accuracy_metric.result().numpy(), 4))
print("Precision  :", round(precision_metric.result().numpy(), 4))
print("Recall     :", round(recall_metric.result().numpy(), 4))
# Out:
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 239ms/step
#
#  Evaluation Metrics on Test Set
# Mean IoU   : 0.9703
# Accuracy   : 0.9933
# Precision  : 0.9807
# Recall     : 0.9663

# %%
import tensorflow as tf
from matplotlib.colors import ListedColormap
from tensorflow.keras.metrics import MeanIoU, Accuracy, Precision, Recall
import numpy as np

# with open("weights_tf10_compatible.pkl", "rb") as f:
#     weights = pickle.load(f)
model.load_weights('my_model_weights.weights.h5')

miou_metric = MeanIoU(num_classes=2)
accuracy_metric = Accuracy()
precision_metric = Precision()
recall_metric = Recall()

num_classes = 2
confusion_matrix = np.zeros((num_classes, num_classes), dtype=np.int64)

cmap = ListedColormap(['black', 'green', 'red'])

for image, mask in dataset_test:
    logits = model.predict(image)
    pred_mask = tf.argmax(logits, axis=-1)           # (B, H, W)
    pred_mask = pred_mask[..., tf.newaxis]           # (B, H, W, 1)

    for i in range(image.shape[0]):
        if mask[i].shape[-1] > 1:
            true_mask = tf.argmax(mask[i], axis=-1)
        else:
            true_mask = tf.squeeze(mask[i])
        true_mask = tf.cast(true_mask, tf.int32)

        pred = tf.squeeze(pred_mask[i])
        pred = tf.cast(pred, tf.int32)

        miou_metric.update_state(true_mask, pred)
        accuracy_metric.update_state(true_mask, pred)
        precision_metric.update_state(true_mask, pred)
        recall_metric.update_state(true_mask, pred)

        y_true = tf.reshape(true_mask, [-1])
        y_pred = tf.reshape(pred, [-1])
        cm = tf.math.confusion_matrix(y_true, y_pred, num_classes=num_classes).numpy()
        confusion_matrix += cm

dice_per_class = []
for i in range(num_classes):
    TP = confusion_matrix[i, i]
    FP = np.sum(confusion_matrix[:, i]) - TP
    FN = np.sum(confusion_matrix[i, :]) - TP
    denom = 2 * TP + FP + FN
    dice = 2 * TP / denom if denom > 0 else 0.0
    dice_per_class.append(dice)

mean_dice = np.mean(dice_per_class)

print("\n Evaluation Metrics on Test Set")
print("Mean IoU   :", round(miou_metric.result().numpy(), 4))
print("Accuracy   :", round(accuracy_metric.result().numpy(), 4))
print("Precision  :", round(precision_metric.result().numpy(), 4))
print("Recall     :", round(recall_metric.result().numpy(), 4))
print("Dice Coef. :", [f"Class {i}: {round(d, 4)}" for i, d in enumerate(dice_per_class)])
print("Mean Dice  :", round(mean_dice, 4))
# Out:
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
#
#  Evaluation Metrics on Test Set
# Mean IoU   : 0.9703
# Accuracy   : 0.9933
# Precision  : 0.9807
# Recall     : 0.9663
# Dice Coef. : ['Class 0: 0.9962', 'Class 1: 0.9734']
# Mean Dice  : 0.9848
