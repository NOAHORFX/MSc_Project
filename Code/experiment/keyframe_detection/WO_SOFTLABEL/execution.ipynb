# %%
from sequence_trainer_tf import train_sequence_model
model, val_files = train_sequence_model(
    feature_dir="/home/featurize/data/features_segmodel",
    input_shape=(115, 6144),
    batch_size=16,
    epochs=30,
    model_save_path="best_sequence_model_v1.h5"
)
# Out:
# 2025-08-14 02:53:26.205572: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-14 02:53:26.236028: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-08-14 02:53:26.835293: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-08-14 02:53:27.757079: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-14 02:53:27.761039: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-14 02:53:27.761182: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-14 02:53:27.762237: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-14 02:53:27.762381: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-14 02:53:27.762488: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-14 02:53:28.137131: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-14 02:53:28.137304: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-14 02:53:28.137418: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-08-14 02:53:28.137493: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-08-14 02:53:28.137519: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22108 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:10:00.0, compute capability: 8.9
# [INFO] Starting training...
# [Callback] sim_weight updated to: 0.0000
# Epoch 1/30
# 2025-08-14 02:53:36.206651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# Could not load symbol cublasGetSmCountTarget from libcublas.so.11. Error: /usr/local/cuda-11.2/targets/x86_64-linux/lib/libcublas.so.11: undefined symbol: cublasGetSmCountTarget
# 2025-08-14 02:53:36.448686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-08-14 02:53:36.451515: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f83e8168eb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-08-14 02:53:36.451767: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-08-14 02:53:36.459973: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-08-14 02:53:36.639473: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#      89/Unknown - 12s 43ms/step - loss: 0.0307 - mae: 0.0953
# 2025-08-14 02:53:41.233652: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 2781345073296494675
# 2025-08-14 02:53:41.233720: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 4066880979417720255
# 2025-08-14 02:53:41.233736: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 12724863230341644127
# 2025-08-14 02:53:41.233749: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 11135657201841802192
# 2025-08-14 02:53:41.233759: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 15600699273045949570
# Epoch 1: val_loss improved from inf to 0.02670, saving model to best_sequence_model_v1.h5
# 2025-08-14 02:53:43.680147: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 9912455701952132064
# 2025-08-14 02:53:43.680240: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 10684174024282981097
# 2025-08-14 02:53:43.680256: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 15180665800545448477
# 2025-08-14 02:53:43.680300: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 1965493651285267280
# 2025-08-14 02:53:43.680311: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 18020854652468368728
# 2025-08-14 02:53:43.680322: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 16736327732786907040
# 2025-08-14 02:53:43.680333: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 1966045385192567832
# 2025-08-14 02:53:43.680344: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 12130909069557877670
# 2025-08-14 02:53:43.680384: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 5280130024810020226
# /environment/miniconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 90/90 [==============================] - 15s 73ms/step - loss: 0.0307 - mae: 0.0949 - val_loss: 0.0267 - val_mae: 0.0907 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0067
# Epoch 2/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0264 - mae: 0.0940
# Epoch 2: val_loss did not improve from 0.02670
# 90/90 [==============================] - 5s 56ms/step - loss: 0.0264 - mae: 0.0940 - val_loss: 0.0360 - val_mae: 0.1968 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0133
# Epoch 3/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0251 - mae: 0.0922
# Epoch 3: val_loss improved from 0.02670 to 0.02308, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 54ms/step - loss: 0.0251 - mae: 0.0918 - val_loss: 0.0231 - val_mae: 0.0622 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0200
# Epoch 4/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0251 - mae: 0.0943
# Epoch 4: val_loss improved from 0.02308 to 0.02272, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 55ms/step - loss: 0.0251 - mae: 0.0943 - val_loss: 0.0227 - val_mae: 0.1087 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0267
# Epoch 5/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0248 - mae: 0.0875
# Epoch 5: val_loss did not improve from 0.02272
# 90/90 [==============================] - 5s 49ms/step - loss: 0.0248 - mae: 0.0871 - val_loss: 0.0293 - val_mae: 0.0524 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0333
# Epoch 6/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0246 - mae: 0.0890
# Epoch 6: val_loss improved from 0.02272 to 0.02052, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 54ms/step - loss: 0.0246 - mae: 0.0890 - val_loss: 0.0205 - val_mae: 0.0767 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0400
# Epoch 7/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0251 - mae: 0.0865
# Epoch 7: val_loss did not improve from 0.02052
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0252 - mae: 0.0868 - val_loss: 0.0294 - val_mae: 0.1067 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0467
# Epoch 8/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0256 - mae: 0.0847
# Epoch 8: val_loss did not improve from 0.02052
# 90/90 [==============================] - 5s 54ms/step - loss: 0.0256 - mae: 0.0847 - val_loss: 0.0286 - val_mae: 0.0414 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0533
# Epoch 9/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0205 - mae: 0.0758
# Epoch 9: val_loss improved from 0.02052 to 0.01828, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 57ms/step - loss: 0.0205 - mae: 0.0756 - val_loss: 0.0183 - val_mae: 0.0605 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0600
# Epoch 10/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0192 - mae: 0.0643
# Epoch 10: val_loss did not improve from 0.01828
# 90/90 [==============================] - 5s 52ms/step - loss: 0.0191 - mae: 0.0642 - val_loss: 0.0195 - val_mae: 0.0496 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0667
# Epoch 11/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0205 - mae: 0.0645
# Epoch 11: val_loss did not improve from 0.01828
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0206 - mae: 0.0644 - val_loss: 0.0208 - val_mae: 0.0467 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0733
# Epoch 12/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0192 - mae: 0.0634
# Epoch 12: val_loss did not improve from 0.01828
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 90/90 [==============================] - 5s 51ms/step - loss: 0.0192 - mae: 0.0634 - val_loss: 0.0212 - val_mae: 0.0517 - lr: 0.0010
# [Callback] sim_weight updated to: 0.0800
# Epoch 13/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0177 - mae: 0.0546
# Epoch 13: val_loss did not improve from 0.01828
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0178 - mae: 0.0548 - val_loss: 0.0205 - val_mae: 0.0756 - lr: 5.0000e-04
# [Callback] sim_weight updated to: 0.0867
# Epoch 14/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0167 - mae: 0.0534
# Epoch 14: val_loss improved from 0.01828 to 0.01707, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 56ms/step - loss: 0.0166 - mae: 0.0533 - val_loss: 0.0171 - val_mae: 0.0472 - lr: 5.0000e-04
# [Callback] sim_weight updated to: 0.0933
# Epoch 15/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0173 - mae: 0.0534
# Epoch 15: val_loss improved from 0.01707 to 0.01660, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 55ms/step - loss: 0.0172 - mae: 0.0533 - val_loss: 0.0166 - val_mae: 0.0450 - lr: 5.0000e-04
# [Callback] sim_weight updated to: 0.1000
# Epoch 16/30
# 90/90 [==============================] - ETA: 0s - loss: 0.0162 - mae: 0.0505
# Epoch 16: val_loss did not improve from 0.01660
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0162 - mae: 0.0505 - val_loss: 0.0176 - val_mae: 0.0669 - lr: 5.0000e-04
# [Callback] sim_weight updated to: 0.1067
# Epoch 17/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0172 - mae: 0.0555
# Epoch 17: val_loss did not improve from 0.01660
# 90/90 [==============================] - 5s 52ms/step - loss: 0.0171 - mae: 0.0555 - val_loss: 0.0173 - val_mae: 0.0650 - lr: 5.0000e-04
# [Callback] sim_weight updated to: 0.1133
# Epoch 18/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0161 - mae: 0.0514
# Epoch 18: val_loss did not improve from 0.01660
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 90/90 [==============================] - 6s 59ms/step - loss: 0.0161 - mae: 0.0516 - val_loss: 0.0177 - val_mae: 0.0646 - lr: 5.0000e-04
# [Callback] sim_weight updated to: 0.1200
# Epoch 19/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0152 - mae: 0.0473
# Epoch 19: val_loss improved from 0.01660 to 0.01614, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 54ms/step - loss: 0.0152 - mae: 0.0474 - val_loss: 0.0161 - val_mae: 0.0505 - lr: 2.5000e-04
# [Callback] sim_weight updated to: 0.1267
# Epoch 20/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0162 - mae: 0.0511
# Epoch 20: val_loss improved from 0.01614 to 0.01610, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 52ms/step - loss: 0.0162 - mae: 0.0513 - val_loss: 0.0161 - val_mae: 0.0483 - lr: 2.5000e-04
# [Callback] sim_weight updated to: 0.1333
# Epoch 21/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0152 - mae: 0.0461
# Epoch 21: val_loss improved from 0.01610 to 0.01584, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 54ms/step - loss: 0.0152 - mae: 0.0461 - val_loss: 0.0158 - val_mae: 0.0489 - lr: 2.5000e-04
# [Callback] sim_weight updated to: 0.1400
# Epoch 22/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0149 - mae: 0.0468
# Epoch 22: val_loss improved from 0.01584 to 0.01564, saving model to best_sequence_model_v1.h5
# 90/90 [==============================] - 5s 56ms/step - loss: 0.0148 - mae: 0.0467 - val_loss: 0.0156 - val_mae: 0.0429 - lr: 2.5000e-04
# [Callback] sim_weight updated to: 0.1467
# Epoch 23/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0150 - mae: 0.0479
# Epoch 23: val_loss did not improve from 0.01564
# 90/90 [==============================] - 5s 55ms/step - loss: 0.0150 - mae: 0.0480 - val_loss: 0.0162 - val_mae: 0.0500 - lr: 2.5000e-04
# [Callback] sim_weight updated to: 0.1533
# Epoch 24/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0155 - mae: 0.0474
# Epoch 24: val_loss did not improve from 0.01564
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0154 - mae: 0.0473 - val_loss: 0.0157 - val_mae: 0.0422 - lr: 2.5000e-04
# [Callback] sim_weight updated to: 0.1600
# Epoch 25/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0147 - mae: 0.0465
# Epoch 25: val_loss did not improve from 0.01564
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 90/90 [==============================] - 5s 54ms/step - loss: 0.0147 - mae: 0.0466 - val_loss: 0.0157 - val_mae: 0.0465 - lr: 2.5000e-04
# [Callback] sim_weight updated to: 0.1667
# Epoch 26/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0142 - mae: 0.0439
# Epoch 26: val_loss did not improve from 0.01564
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0143 - mae: 0.0441 - val_loss: 0.0164 - val_mae: 0.0533 - lr: 1.2500e-04
# [Callback] sim_weight updated to: 0.1733
# Epoch 27/30
# 89/90 [============================>.] - ETA: 0s - loss: 0.0144 - mae: 0.0443Restoring model weights from the end of the best epoch: 22.
#
# Epoch 27: val_loss did not improve from 0.01564
# 90/90 [==============================] - 5s 54ms/step - loss: 0.0144 - mae: 0.0443 - val_loss: 0.0158 - val_mae: 0.0438 - lr: 1.2500e-04
# Epoch 27: early stopping
# [INFO] Best model saved to: best_sequence_model_v1.h5

# %%
import random
from evaluate_prediction_tf import evaluate_and_visualize_predictions

print(random.choice(val_files))
# Out:
# /home/featurize/data/features_segmodel/ec65aa35-d54c-44da-80a4-883f631c345e/sweep_1/features.npy

# %%
evaluate_and_visualize_predictions(
    model_path="best_sequence_model_v1.h5",
    npy_file="/home/featurize/data/features_segmodel/ced55401-e5ba-4da3-b24f-57b711f604bf/sweep_2/features.npy",
    smooth_method='gaussian'
)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Prediction std: 0.1703
# Detected 1 relative peaks
# Predicted key frames: [46, 45, 47]
# Scores: [0.6504227, 0.64377517, 0.63611317]

# %%
from evaluate_hit_rate_1 import evaluate_keyframe_hit_rate
# evaluate_keyframe_hit_rate(
#     "best_sequence_model_v1.h5", 
#     val_files, 
#     score_threshold=0.3
# )

evaluate_keyframe_hit_rate(
    model_path="best_sequence_model_v1.h5",
    val_feature_files=val_files,
    score_threshold=0.7,
    smooth_method='gaussian',
    exclude_margin=10,
    save_dir="proof_images",  # 保存证明效果的图
    max_visualize=6
)
# Out:
# === Key Frame Hit Rate Evaluation ===
# Valid Files Evaluated : 109
# Threshold             : score ≥ 0.7
# Margin Excluded       : 10 frames
# Match Tolerance       : ±2 frames
# Total Predicted Frames: 487
# Total Hits (GT ≥ 0.5) : 427
# Overall Hit Ratio     : 0.8768  (micro, threshold-based)
# Avg Hit Ratio/File    : 0.4161 (macro, threshold-based)
# Mean Recall@K         : 0.7671  (macro, K=#GT, tolerance-aware)
# Mean Hit@1            : 0.7963  (macro, tolerance-aware)
# Visualizations saved to: proof_images

# %%
from position_bias_batch_2 import position_bias_batch

summary = position_bias_batch(
    model_path="best_sequence_model_v1.h5",
    val_feature_files=val_files,
    exclude_margin=10,
    selection='topk',       # 或 'threshold'
    score_threshold=0.7,
    tolerance=2,
    smooth_method='gaussian'
)

print("\nSummary:", summary)
# Out:
# === Keyframe Position Bias Evaluation (Batch) ===
# Files evaluated     : 109
# Mean abs error      : 5.65 frames
# Median abs error    : 5.42 frames
# 95% abs error ≤     : 8.01 frames
# Mean bias direction : 0.16 frames (pos=late, neg=early)
# Recall              : 74.81%
# Precision           : 74.81%
#
# Summary: {'n_files': 109, 'mean_abs_err_frames': 5.648320067438773, 'median_abs_err_frames': 5.422018348623853, 'p95_abs_err_frames': 8.008715596330275, 'bias_frames': 0.15797054156015394, 'recall': 0.7480924934662364, 'precision': 0.7480924934662364}

# %%
from frame_level_metrics import compute_frame_level_metrics
from glob import glob

compute_frame_level_metrics(
    model_path="best_sequence_model_v1.h5",
    feature_files=val_files,
    margin_exclude=10,
    threshold=0.7
)
# Out:
# === Frame-Level Evaluation ===
# Samples evaluated: 360
# Excluded margin: 10 frames
# ROC-AUC   : 0.9380
# mAP       : 0.7112
# Precision : 0.7930
# Recall    : 0.3596
# F1-score  : 0.4948
# {'ROC-AUC': 0.9380367627480446,
#  'mAP': 0.7111569886393923,
#  'Precision': 0.7930434782608695,
#  'Recall': 0.35962145110410093,
#  'F1-score': 0.49484536082474223}

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_label_distribution(val_feature_files):
    total_1 = 0
    total_05 = 0
    total_0 = 0
    total_frames = 0

    for path in val_feature_files:
        data = np.load(path, allow_pickle=True).item()
        labels = data["labels"]

        total_1 += np.sum(labels == 1.0)
        total_05 += np.sum(labels == 0.5)
        total_0 += np.sum(labels == 0.0)
        total_frames += len(labels)

    # 打印汇总
    print("=== Label Distribution Across All Files ===")
    print(f"Label 1.0 (best):     {total_1}")
    print(f"Label 0.5 (second):   {total_05}")
    print(f"Label 0.0 (non-key):  {total_0}")
    print(f"Total frames:         {total_frames}")

    # 绘图
    labels = ['1.0 (best)', '0.5 (second best)', '0.0 (non-key)']
    counts = [total_1, total_05, total_0]

    plt.figure(figsize=(6, 4))
    plt.bar(labels, counts)
    plt.title("Label Count Distribution (All Validation Files)")
    plt.ylabel("Frame Count")
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

    return {
        "label_1.0": total_1,
        "label_0.5": total_05,
        "label_0.0": total_0,
        "total_frames": total_frames
    }


plot_label_distribution(val_files)
# Out:
# === Label Distribution Across All Files ===
# Label 1.0 (best):     376
# Label 0.5 (second):   931
# Label 0.0 (non-key):  40093
# Total frames:         41400
# {'label_1.0': 376, 'label_0.5': 931, 'label_0.0': 40093, 'total_frames': 41400}
